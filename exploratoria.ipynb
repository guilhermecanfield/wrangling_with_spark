# %%
# Importando as bibliotecas que utilizaremos durante a aula
from pyspark import SparkConf
from pyspark.sql import SparkSession
import findspark
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Encontrando as configurações para inicializar o Spark
findspark.init()

# %%
# Nome da aplicação Spark
app_name = "Aplicação Spark"

# Inicializando o objeto de configurações do Spark
conf = SparkConf()
conf.set("spark.hadoop.security.authentication", "simple")
# Configuração do tipo de cluster
conf.set("spark.master", "local[*]")
# Definição do nome da aplicação
conf.set("spark.app.name", app_name)
# Definição da quantidade de núcleos de processamento a serem usados
conf.set("spark.executor.cores", "2")
# Definição da quantidade de memória alocada para cada executor
conf.set("spark.executor.memory", "2g")
conf.set("spark.driver.memory", "2g")

# Criando a sessão Spark
spark = SparkSession.builder.config(conf=conf).getOrCreate()

print("Spark inicializado com sucesso!")
# Out:
# Spark inicializado com sucesso!

# %% [markdown]
# ### Data Wrangling

# %%
# FONTE: https://www.kaggle.com/datasets/yuanyuwendymu/airline-delay-and-cance
# llation-data-2009-2018

# Lendo um DataFrame Spark a partir de um arquivo CSV
df = spark.read.csv("./datasets/2016.csv", header=True, inferSchema=True)

# %%
# Exibindo os dados do DataFrame
df.show()
# Out:
# +----------+----------+-----------------+------+----+------------+--------+---------+--------+----------+---------+-------+------------+--------+---------+---------+-----------------+--------+----------------+-------------------+--------+--------+-------------+-------------+---------+--------------+-------------------+-----------+
# |   FL_DATE|OP_CARRIER|OP_CARRIER_FL_NUM|ORIGIN|DEST|CRS_DEP_TIME|DEP_TIME|DEP_DELAY|TAXI_OUT|WHEELS_OFF|WHEELS_ON|TAXI_IN|CRS_ARR_TIME|ARR_TIME|ARR_DELAY|CANCELLED|CANCELLATION_CODE|DIVERTED|CRS_ELAPSED_TIME|ACTUAL_ELAPSED_TIME|AIR_TIME|DISTANCE|CARRIER_DELAY|WEATHER_DELAY|NAS_DELAY|SECURITY_DELAY|LATE_AIRCRAFT_DELAY|Unnamed: 27|
# +----------+----------+-----------------+------+----+------------+--------+---------+--------+----------+---------+-------+------------+--------+---------+---------+-----------------+--------+----------------+-------------------+--------+--------+-------------+-------------+---------+--------------+-------------------+-----------+
# |2016-01-01|        DL|             1248|   DTW| LAX|        1935|  1935.0|      0.0|    23.0|    1958.0|   2107.0|   13.0|        2144|  2120.0|    -24.0|      0.0|             NULL|     0.0|           309.0|              285.0|   249.0|  1979.0|         NULL|         NULL|     NULL|          NULL|               NULL|       NULL|
# |2016-01-01|        DL|             1251|   ATL| GRR|        2125|  2130.0|      5.0|    13.0|    2143.0|   2315.0|    4.0|        2321|  2319.0|     -2.0|      0.0|             NULL|     0.0|           116.0|              109.0|    92.0|   640.0|         NULL|         NULL|     NULL|          NULL|               NULL|       NULL|
# |2016-01-01|        DL|             1254|   LAX| ATL|        2255|  2256.0|      1.0|    19.0|    2315.0|    542.0|    5.0|         600|   547.0|    -13.0|      0.0|             NULL|     0.0|           245.0|              231.0|   207.0|  1947.0|         NULL|         NULL|     NULL|          NULL|               NULL|       NULL|
# |2016-01-01|        DL|             1255|   SLC| ATL|        1656|  1700.0|      4.0|    12.0|    1712.0|   2205.0|    8.0|        2229|  2213.0|    -16.0|      0.0|             NULL|     0.0|           213.0|              193.0|   173.0|  1590.0|         NULL|         NULL|     NULL|          NULL|               NULL|       NULL|
# |2016-01-01|        DL|             1256|   BZN| MSP|         900|  1012.0|     72.0|    63.0|    1115.0|   1416.0|    4.0|        1216|  1420.0|    124.0|      0.0|             NULL|     0.0|           136.0|              188.0|   121.0|   874.0|         72.0|          0.0|     52.0|           0.0|                0.0|       NULL|
# |2016-01-01|        DL|             1257|   ATL| BNA|        1233|  1356.0|     83.0|    22.0|    1418.0|   1356.0|    6.0|        1239|  1402.0|     83.0|      0.0|             NULL|     0.0|            66.0|               66.0|    38.0|   214.0|         43.0|          0.0|      0.0|           0.0|               40.0|       NULL|
# |2016-01-01|        DL|             1257|   BNA| ATL|        1320|  1446.0|     86.0|    15.0|    1501.0|   1638.0|    6.0|        1530|  1644.0|     74.0|      0.0|             NULL|     0.0|            70.0|               58.0|    37.0|   214.0|          3.0|          0.0|      0.0|           0.0|               71.0|       NULL|
# |2016-01-01|        DL|             1258|   ATL| JAX|         945|   946.0|      1.0|    19.0|    1005.0|   1050.0|    3.0|        1050|  1053.0|      3.0|      0.0|             NULL|     0.0|            65.0|               67.0|    45.0|   270.0|         NULL|         NULL|     NULL|          NULL|               NULL|       NULL|
# |2016-01-01|        DL|             1258|   JAX| ATL|        1145|  1144.0|     -1.0|    12.0|    1156.0|   1239.0|    8.0|        1302|  1247.0|    -15.0|      0.0|             NULL|     0.0|            77.0|               63.0|    43.0|   270.0|         NULL|         NULL|     NULL|          NULL|               NULL|       NULL|
# |2016-01-01|        DL|             1259|   ATL| OKC|        2110|  2107.0|     -3.0|    16.0|    2123.0|   2219.0|    5.0|        2236|  2224.0|    -12.0|      0.0|             NULL|     0.0|           146.0|              137.0|   116.0|   761.0|         NULL|         NULL|     NULL|          NULL|               NULL|       NULL|
# |2016-01-01|        DL|             1260|   MSP| SMF|        1115|  1113.0|     -2.0|    12.0|    1125.0|   1232.0|    4.0|        1309|  1236.0|    -33.0|      0.0|             NULL|     0.0|           234.0|              203.0|   187.0|  1517.0|         NULL|         NULL|     NULL|          NULL|               NULL|       NULL|
# |2016-01-01|        DL|             1262|   LAX| JFK|        2255|  2248.0|     -7.0|    23.0|    2311.0|    650.0|   11.0|         715|   701.0|    -14.0|      0.0|             NULL|     0.0|           320.0|              313.0|   279.0|  2475.0|         NULL|         NULL|     NULL|          NULL|               NULL|       NULL|
# |2016-01-01|        DL|             1263|   ATL| MDT|        1510|  1509.0|     -1.0|    17.0|    1526.0|   1646.0|    5.0|        1702|  1651.0|    -11.0|      0.0|             NULL|     0.0|           112.0|              102.0|    80.0|   620.0|         NULL|         NULL|     NULL|          NULL|               NULL|       NULL|
# |2016-01-01|        DL|             1263|   MDT| ATL|        1737|  1727.0|    -10.0|    11.0|    1738.0|   1923.0|   11.0|        1949|  1934.0|    -15.0|      0.0|             NULL|     0.0|           132.0|              127.0|   105.0|   620.0|         NULL|         NULL|     NULL|          NULL|               NULL|       NULL|
# |2016-01-01|        DL|             1264|   SLC| JFK|        2345|  2341.0|     -4.0|    25.0|       6.0|    602.0|   11.0|         607|   613.0|      6.0|      0.0|             NULL|     0.0|           262.0|              272.0|   236.0|  1990.0|         NULL|         NULL|     NULL|          NULL|               NULL|       NULL|
# |2016-01-01|        DL|             1265|   SAV| ATL|        1408|  1403.0|     -5.0|    15.0|    1418.0|   1459.0|    6.0|        1523|  1505.0|    -18.0|      0.0|             NULL|     0.0|            75.0|               62.0|    41.0|   214.0|         NULL|         NULL|     NULL|          NULL|               NULL|       NULL|
# |2016-01-01|        DL|             1266|   BUF| ATL|         615|   612.0|     -3.0|    38.0|     650.0|    844.0|    5.0|         843|   849.0|      6.0|      0.0|             NULL|     0.0|           148.0|              157.0|   114.0|   712.0|         NULL|         NULL|     NULL|          NULL|               NULL|       NULL|
# |2016-01-01|        DL|             1269|   LGA| MIA|        1100|  1100.0|      0.0|    15.0|    1115.0|   1402.0|    4.0|        1432|  1406.0|    -26.0|      0.0|             NULL|     0.0|           212.0|              186.0|   167.0|  1096.0|         NULL|         NULL|     NULL|          NULL|               NULL|       NULL|
# |2016-01-01|        DL|             1270|   ATL| PNS|        1340|  1337.0|     -3.0|    11.0|    1348.0|   1339.0|    3.0|        1352|  1342.0|    -10.0|      0.0|             NULL|     0.0|            72.0|               65.0|    51.0|   271.0|         NULL|         NULL|     NULL|          NULL|               NULL|       NULL|
# |2016-01-01|        DL|             1270|   PNS| ATL|        1435|  1431.0|     -4.0|    10.0|    1441.0|   1622.0|    6.0|        1648|  1628.0|    -20.0|      0.0|             NULL|     0.0|            73.0|               57.0|    41.0|   271.0|         NULL|         NULL|     NULL|          NULL|               NULL|       NULL|
# +----------+----------+-----------------+------+----+------------+--------+---------+--------+----------+---------+-------+------------+--------+---------+---------+-----------------+--------+----------------+-------------------+--------+--------+-------------+-------------+---------+--------------+-------------------+-----------+
# only showing top 20 rows

# %%
# Exibindo uma linha do DataFrame em formato vertical
df.show(1, vertical=True)
# Out:
# -RECORD 0-------------------------
#  FL_DATE             | 2016-01-01
#  OP_CARRIER          | DL
#  OP_CARRIER_FL_NUM   | 1248
#  ORIGIN              | DTW
#  DEST                | LAX
#  CRS_DEP_TIME        | 1935
#  DEP_TIME            | 1935.0
#  DEP_DELAY           | 0.0
#  TAXI_OUT            | 23.0
#  WHEELS_OFF          | 1958.0
#  WHEELS_ON           | 2107.0
#  TAXI_IN             | 13.0
#  CRS_ARR_TIME        | 2144
#  ARR_TIME            | 2120.0
#  ARR_DELAY           | -24.0
#  CANCELLED           | 0.0
#  CANCELLATION_CODE   | NULL
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 309.0
#  ACTUAL_ELAPSED_TIME | 285.0
#  AIR_TIME            | 249.0
#  DISTANCE            | 1979.0
#  CARRIER_DELAY       | NULL
#  WEATHER_DELAY       | NULL
#  NAS_DELAY           | NULL
#  SECURITY_DELAY      | NULL
#  LATE_AIRCRAFT_DELAY | NULL
#  Unnamed: 27         | NULL
# only showing top 1 row

# %%
# Exibindo o esquema do DataFrame (nome das colunas e tipos)
df.printSchema()

# FL_DATE                      | DATA_VOO
# OP_CARRIER                   | TRANSPORTADORA
# OP_CARRIER_FL_NUM            | NUM_VOO_TRANSPORTADORA
# ORIGIN                       | ORIGEM
# DEST                         | DESTINO
# CRS_DEP_TIME                 | HORARIO_PARTIDA_PROGRAMADO
# DEP_TIME                     | HORARIO_PARTIDA_REAL
# DEP_DELAY                    | ATRASO_PARTIDA
# TAXI_OUT                     | TAXI_OUT
# WHEELS_OFF                   | HORARIO_DECOLAGEM
# WHEELS_ON                    | HORARIO_POUSO
# TAXI_IN                      | TAXI_IN
# CRS_ARR_TIME                 | HORARIO_CHEGADA_PROGRAMADO
# ARR_TIME                     | HORARIO_CHEGADA_REAL
# ARR_DELAY                    | ATRASO_CHEGADA
# CANCELLED                    | CANCELADO
# CANCELLATION_CODE            | CODIGO_CANCELAMENTO
# DIVERTED                     | DESVIADO
# CRS_ELAPSED_TIME             | TEMPO_DE_VOO_PROGRAMADO
# ACTUAL_ELAPSED_TIME          | TEMPO_DE_VOO_REAL
# AIR_TIME                     | TEMPO_DE_VOO_EM_AR
# DISTANCE                     | DISTANCIA
# CARRIER_DELAY                | ATRASO_DA_TRANSPORTADORA
# WEATHER_DELAY                | ATRASO_DE_CLIMA
# NAS_DELAY                    | ATRASO_NAS
# SECURITY_DELAY               | ATRASO_DE_SEGURANCA
# LATE_AIRCRAFT_DELAY          | ATRASO_DE_AERONAVE_TARDE
# Out:
# root
#  |-- FL_DATE: date (nullable = true)
#  |-- OP_CARRIER: string (nullable = true)
#  |-- OP_CARRIER_FL_NUM: integer (nullable = true)
#  |-- ORIGIN: string (nullable = true)
#  |-- DEST: string (nullable = true)
#  |-- CRS_DEP_TIME: integer (nullable = true)
#  |-- DEP_TIME: double (nullable = true)
#  |-- DEP_DELAY: double (nullable = true)
#  |-- TAXI_OUT: double (nullable = true)
#  |-- WHEELS_OFF: double (nullable = true)
#  |-- WHEELS_ON: double (nullable = true)
#  |-- TAXI_IN: double (nullable = true)
#  |-- CRS_ARR_TIME: integer (nullable = true)
#  |-- ARR_TIME: double (nullable = true)
#  |-- ARR_DELAY: double (nullable = true)
#  |-- CANCELLED: double (nullable = true)
#  |-- CANCELLATION_CODE: string (nullable = true)
#  |-- DIVERTED: double (nullable = true)
#  |-- CRS_ELAPSED_TIME: double (nullable = true)
#  |-- ACTUAL_ELAPSED_TIME: double (nullable = true)
#  |-- AIR_TIME: double (nullable = true)
#  |-- DISTANCE: double (nullable = true)
#  |-- CARRIER_DELAY: double (nullable = true)
#  |-- WEATHER_DELAY: double (nullable = true)
#  |-- NAS_DELAY: double (nullable = true)
#  |-- SECURITY_DELAY: double (nullable = true)
#  |-- LATE_AIRCRAFT_DELAY: double (nullable = true)
#  |-- Unnamed: 27: string (nullable = true)

# %%
# Criando um DataFrame com colunas selecionadas
df_selecionado = df.select(["DISTANCE", "ACTUAL_ELAPSED_TIME", "ARR_DELAY"])

# %%
# Exibindo o DataFrame com as colunas selecionadas
df_selecionado.show()
# Out:
# +--------+-------------------+---------+
# |DISTANCE|ACTUAL_ELAPSED_TIME|ARR_DELAY|
# +--------+-------------------+---------+
# |  1979.0|              285.0|    -24.0|
# |   640.0|              109.0|     -2.0|
# |  1947.0|              231.0|    -13.0|
# |  1590.0|              193.0|    -16.0|
# |   874.0|              188.0|    124.0|
# |   214.0|               66.0|     83.0|
# |   214.0|               58.0|     74.0|
# |   270.0|               67.0|      3.0|
# |   270.0|               63.0|    -15.0|
# |   761.0|              137.0|    -12.0|
# |  1517.0|              203.0|    -33.0|
# |  2475.0|              313.0|    -14.0|
# |   620.0|              102.0|    -11.0|
# |   620.0|              127.0|    -15.0|
# |  1990.0|              272.0|      6.0|
# |   214.0|               62.0|    -18.0|
# |   712.0|              157.0|      6.0|
# |  1096.0|              186.0|    -26.0|
# |   271.0|               65.0|    -10.0|
# |   271.0|               57.0|    -20.0|
# +--------+-------------------+---------+
# only showing top 20 rows

# %%
# Visualizando as análises univariadas
df_selecionado.describe().show()
# Out:
# +-------+-----------------+-------------------+------------------+
# |summary|         DISTANCE|ACTUAL_ELAPSED_TIME|         ARR_DELAY|
# +-------+-----------------+-------------------+------------------+
# |  count|          5617658|            5538145|           5538145|
# |   mean|850.0785813233914| 140.16078867563056|3.5192899427515894|
# | stddev|619.5001373392853|  75.66282676521725| 41.87331683749174|
# |    min|             25.0|               14.0|            -152.0|
# |    max|           4983.0|              778.0|            2142.0|
# +-------+-----------------+-------------------+------------------+

# %%
# contagem de linhas do dataset
total_linhas = df.count()

print(f"Total de linhas no dataset: {total_linhas} \n")
# Out:
# Total de linhas no dataset: 5617658

# %%
# verificando o número de partições utilizadas no processamento distribuído
df.rdd.getNumPartitions()
# Out:
# 8

# %%
# coletando uma pequena amostra equivalente a 1%
pequena_amostra = df.sample(fraction=0.01)

# %%
# contagem de linhas do dataset reduzido
total_linhas_pequena_amostra = pequena_amostra.count()

print(f"Total de linhas no dataset: {total_linhas_pequena_amostra} \n")
# Out:
# Total de linhas no dataset: 56116

# %%
# estratégia da extrapolação para calcular grandes volumes de dados
total_linhas_extrapoladas = int(total_linhas_pequena_amostra / 0.01)

print(f"Total de linhas no dataset: {total_linhas_extrapoladas} \n")
# Out:
# Total de linhas no dataset: 5611600

# %%
# Tratando dados temporais

#  Importando funções úteis do PySpark para tratamento de dados
import pyspark.sql.functions as F

# Documentação: https://spark.apache.org/docs/latest/api/python/reference/pyspark.sql/functions.html

# Extraindo o ano da variável FL_DATE
df = df.withColumn("ano", F.year(df["FL_DATE"]))

# Extraindo o mês da variável FL_DATE
df = df.withColumn("mes", F.month(df["FL_DATE"]))

# Extraindo o dia do mês da variável FL_DATE
df = df.withColumn("dia", F.dayofmonth(df["FL_DATE"]))

# %%
# Exibindo os dados com as novas colunas
df.show(5, vertical=True)
# Out:
# -RECORD 0-------------------------
#  FL_DATE             | 2016-01-01
#  OP_CARRIER          | DL
#  OP_CARRIER_FL_NUM   | 1248
#  ORIGIN              | DTW
#  DEST                | LAX
#  CRS_DEP_TIME        | 1935
#  DEP_TIME            | 1935.0
#  DEP_DELAY           | 0.0
#  TAXI_OUT            | 23.0
#  WHEELS_OFF          | 1958.0
#  WHEELS_ON           | 2107.0
#  TAXI_IN             | 13.0
#  CRS_ARR_TIME        | 2144
#  ARR_TIME            | 2120.0
#  ARR_DELAY           | -24.0
#  CANCELLED           | 0.0
#  CANCELLATION_CODE   | NULL
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 309.0
#  ACTUAL_ELAPSED_TIME | 285.0
#  AIR_TIME            | 249.0
#  DISTANCE            | 1979.0
#  CARRIER_DELAY       | NULL
#  WEATHER_DELAY       | NULL
#  NAS_DELAY           | NULL
#  SECURITY_DELAY      | NULL
#  LATE_AIRCRAFT_DELAY | NULL
#  Unnamed: 27         | NULL
#  ano                 | 2016
#  mes                 | 1
#  dia                 | 1
# -RECORD 1-------------------------
#  FL_DATE             | 2016-01-01
#  OP_CARRIER          | DL
#  OP_CARRIER_FL_NUM   | 1251
#  ORIGIN              | ATL
#  DEST                | GRR
#  CRS_DEP_TIME        | 2125
#  DEP_TIME            | 2130.0
#  DEP_DELAY           | 5.0
#  TAXI_OUT            | 13.0
#  WHEELS_OFF          | 2143.0
#  WHEELS_ON           | 2315.0
#  TAXI_IN             | 4.0
#  CRS_ARR_TIME        | 2321
#  ARR_TIME            | 2319.0
#  ARR_DELAY           | -2.0
#  CANCELLED           | 0.0
#  CANCELLATION_CODE   | NULL
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 116.0
#  ACTUAL_ELAPSED_TIME | 109.0
#  AIR_TIME            | 92.0
#  DISTANCE            | 640.0
#  CARRIER_DELAY       | NULL
#  WEATHER_DELAY       | NULL
#  NAS_DELAY           | NULL
#  SECURITY_DELAY      | NULL
#  LATE_AIRCRAFT_DELAY | NULL
#  Unnamed: 27         | NULL
#  ano                 | 2016
#  mes                 | 1
#  dia                 | 1
# -RECORD 2-------------------------
#  FL_DATE             | 2016-01-01
#  OP_CARRIER          | DL
#  OP_CARRIER_FL_NUM   | 1254
#  ORIGIN              | LAX
#  DEST                | ATL
#  CRS_DEP_TIME        | 2255
#  DEP_TIME            | 2256.0
#  DEP_DELAY           | 1.0
#  TAXI_OUT            | 19.0
#  WHEELS_OFF          | 2315.0
#  WHEELS_ON           | 542.0
#  TAXI_IN             | 5.0
#  CRS_ARR_TIME        | 600
#  ARR_TIME            | 547.0
#  ARR_DELAY           | -13.0
#  CANCELLED           | 0.0
#  CANCELLATION_CODE   | NULL
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 245.0
#  ACTUAL_ELAPSED_TIME | 231.0
#  AIR_TIME            | 207.0
#  DISTANCE            | 1947.0
#  CARRIER_DELAY       | NULL
#  WEATHER_DELAY       | NULL
#  NAS_DELAY           | NULL
#  SECURITY_DELAY      | NULL
#  LATE_AIRCRAFT_DELAY | NULL
#  Unnamed: 27         | NULL
#  ano                 | 2016
#  mes                 | 1
#  dia                 | 1
# -RECORD 3-------------------------
#  FL_DATE             | 2016-01-01
#  OP_CARRIER          | DL
#  OP_CARRIER_FL_NUM   | 1255
#  ORIGIN              | SLC
#  DEST                | ATL
#  CRS_DEP_TIME        | 1656
#  DEP_TIME            | 1700.0
#  DEP_DELAY           | 4.0
#  TAXI_OUT            | 12.0
#  WHEELS_OFF          | 1712.0
#  WHEELS_ON           | 2205.0
#  TAXI_IN             | 8.0
#  CRS_ARR_TIME        | 2229
#  ARR_TIME            | 2213.0
#  ARR_DELAY           | -16.0
#  CANCELLED           | 0.0
#  CANCELLATION_CODE   | NULL
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 213.0
#  ACTUAL_ELAPSED_TIME | 193.0
#  AIR_TIME            | 173.0
#  DISTANCE            | 1590.0
#  CARRIER_DELAY       | NULL
#  WEATHER_DELAY       | NULL
#  NAS_DELAY           | NULL
#  SECURITY_DELAY      | NULL
#  LATE_AIRCRAFT_DELAY | NULL
#  Unnamed: 27         | NULL
#  ano                 | 2016
#  mes                 | 1
#  dia                 | 1
# -RECORD 4-------------------------
#  FL_DATE             | 2016-01-01
#  OP_CARRIER          | DL
#  OP_CARRIER_FL_NUM   | 1256
#  ORIGIN              | BZN
#  DEST                | MSP
#  CRS_DEP_TIME        | 900
#  DEP_TIME            | 1012.0
#  DEP_DELAY           | 72.0
#  TAXI_OUT            | 63.0
#  WHEELS_OFF          | 1115.0
#  WHEELS_ON           | 1416.0
#  TAXI_IN             | 4.0
#  CRS_ARR_TIME        | 1216
#  ARR_TIME            | 1420.0
#  ARR_DELAY           | 124.0
#  CANCELLED           | 0.0
#  CANCELLATION_CODE   | NULL
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 136.0
#  ACTUAL_ELAPSED_TIME | 188.0
#  AIR_TIME            | 121.0
#  DISTANCE            | 874.0
#  CARRIER_DELAY       | 72.0
#  WEATHER_DELAY       | 0.0
#  NAS_DELAY           | 52.0
#  SECURITY_DELAY      | 0.0
#  LATE_AIRCRAFT_DELAY | 0.0
#  Unnamed: 27         | NULL
#  ano                 | 2016
#  mes                 | 1
#  dia                 | 1
# only showing top 5 rows

# %%
# Removendo colunas indesejadas com o método drop
df = df.drop("Unnamed: 27")

# %%
# Exibindo os dados após a exclusão da coluna
df.show(5, vertical=True)
# Out:
# -RECORD 0-------------------------
#  FL_DATE             | 2016-01-01
#  OP_CARRIER          | DL
#  OP_CARRIER_FL_NUM   | 1248
#  ORIGIN              | DTW
#  DEST                | LAX
#  CRS_DEP_TIME        | 1935
#  DEP_TIME            | 1935.0
#  DEP_DELAY           | 0.0
#  TAXI_OUT            | 23.0
#  WHEELS_OFF          | 1958.0
#  WHEELS_ON           | 2107.0
#  TAXI_IN             | 13.0
#  CRS_ARR_TIME        | 2144
#  ARR_TIME            | 2120.0
#  ARR_DELAY           | -24.0
#  CANCELLED           | 0.0
#  CANCELLATION_CODE   | NULL
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 309.0
#  ACTUAL_ELAPSED_TIME | 285.0
#  AIR_TIME            | 249.0
#  DISTANCE            | 1979.0
#  CARRIER_DELAY       | NULL
#  WEATHER_DELAY       | NULL
#  NAS_DELAY           | NULL
#  SECURITY_DELAY      | NULL
#  LATE_AIRCRAFT_DELAY | NULL
#  ano                 | 2016
#  mes                 | 1
#  dia                 | 1
# -RECORD 1-------------------------
#  FL_DATE             | 2016-01-01
#  OP_CARRIER          | DL
#  OP_CARRIER_FL_NUM   | 1251
#  ORIGIN              | ATL
#  DEST                | GRR
#  CRS_DEP_TIME        | 2125
#  DEP_TIME            | 2130.0
#  DEP_DELAY           | 5.0
#  TAXI_OUT            | 13.0
#  WHEELS_OFF          | 2143.0
#  WHEELS_ON           | 2315.0
#  TAXI_IN             | 4.0
#  CRS_ARR_TIME        | 2321
#  ARR_TIME            | 2319.0
#  ARR_DELAY           | -2.0
#  CANCELLED           | 0.0
#  CANCELLATION_CODE   | NULL
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 116.0
#  ACTUAL_ELAPSED_TIME | 109.0
#  AIR_TIME            | 92.0
#  DISTANCE            | 640.0
#  CARRIER_DELAY       | NULL
#  WEATHER_DELAY       | NULL
#  NAS_DELAY           | NULL
#  SECURITY_DELAY      | NULL
#  LATE_AIRCRAFT_DELAY | NULL
#  ano                 | 2016
#  mes                 | 1
#  dia                 | 1
# -RECORD 2-------------------------
#  FL_DATE             | 2016-01-01
#  OP_CARRIER          | DL
#  OP_CARRIER_FL_NUM   | 1254
#  ORIGIN              | LAX
#  DEST                | ATL
#  CRS_DEP_TIME        | 2255
#  DEP_TIME            | 2256.0
#  DEP_DELAY           | 1.0
#  TAXI_OUT            | 19.0
#  WHEELS_OFF          | 2315.0
#  WHEELS_ON           | 542.0
#  TAXI_IN             | 5.0
#  CRS_ARR_TIME        | 600
#  ARR_TIME            | 547.0
#  ARR_DELAY           | -13.0
#  CANCELLED           | 0.0
#  CANCELLATION_CODE   | NULL
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 245.0
#  ACTUAL_ELAPSED_TIME | 231.0
#  AIR_TIME            | 207.0
#  DISTANCE            | 1947.0
#  CARRIER_DELAY       | NULL
#  WEATHER_DELAY       | NULL
#  NAS_DELAY           | NULL
#  SECURITY_DELAY      | NULL
#  LATE_AIRCRAFT_DELAY | NULL
#  ano                 | 2016
#  mes                 | 1
#  dia                 | 1
# -RECORD 3-------------------------
#  FL_DATE             | 2016-01-01
#  OP_CARRIER          | DL
#  OP_CARRIER_FL_NUM   | 1255
#  ORIGIN              | SLC
#  DEST                | ATL
#  CRS_DEP_TIME        | 1656
#  DEP_TIME            | 1700.0
#  DEP_DELAY           | 4.0
#  TAXI_OUT            | 12.0
#  WHEELS_OFF          | 1712.0
#  WHEELS_ON           | 2205.0
#  TAXI_IN             | 8.0
#  CRS_ARR_TIME        | 2229
#  ARR_TIME            | 2213.0
#  ARR_DELAY           | -16.0
#  CANCELLED           | 0.0
#  CANCELLATION_CODE   | NULL
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 213.0
#  ACTUAL_ELAPSED_TIME | 193.0
#  AIR_TIME            | 173.0
#  DISTANCE            | 1590.0
#  CARRIER_DELAY       | NULL
#  WEATHER_DELAY       | NULL
#  NAS_DELAY           | NULL
#  SECURITY_DELAY      | NULL
#  LATE_AIRCRAFT_DELAY | NULL
#  ano                 | 2016
#  mes                 | 1
#  dia                 | 1
# -RECORD 4-------------------------
#  FL_DATE             | 2016-01-01
#  OP_CARRIER          | DL
#  OP_CARRIER_FL_NUM   | 1256
#  ORIGIN              | BZN
#  DEST                | MSP
#  CRS_DEP_TIME        | 900
#  DEP_TIME            | 1012.0
#  DEP_DELAY           | 72.0
#  TAXI_OUT            | 63.0
#  WHEELS_OFF          | 1115.0
#  WHEELS_ON           | 1416.0
#  TAXI_IN             | 4.0
#  CRS_ARR_TIME        | 1216
#  ARR_TIME            | 1420.0
#  ARR_DELAY           | 124.0
#  CANCELLED           | 0.0
#  CANCELLATION_CODE   | NULL
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 136.0
#  ACTUAL_ELAPSED_TIME | 188.0
#  AIR_TIME            | 121.0
#  DISTANCE            | 874.0
#  CARRIER_DELAY       | 72.0
#  WEATHER_DELAY       | 0.0
#  NAS_DELAY           | 52.0
#  SECURITY_DELAY      | 0.0
#  LATE_AIRCRAFT_DELAY | 0.0
#  ano                 | 2016
#  mes                 | 1
#  dia                 | 1
# only showing top 5 rows

# %%
# Selecionando apenas as colunas temporais
df.select("FL_DATE", "ano", "mes", "dia").show()
# Out:
# +----------+----+---+---+
# |   FL_DATE| ano|mes|dia|
# +----------+----+---+---+
# |2016-01-01|2016|  1|  1|
# |2016-01-01|2016|  1|  1|
# |2016-01-01|2016|  1|  1|
# |2016-01-01|2016|  1|  1|
# |2016-01-01|2016|  1|  1|
# |2016-01-01|2016|  1|  1|
# |2016-01-01|2016|  1|  1|
# |2016-01-01|2016|  1|  1|
# |2016-01-01|2016|  1|  1|
# |2016-01-01|2016|  1|  1|
# |2016-01-01|2016|  1|  1|
# |2016-01-01|2016|  1|  1|
# |2016-01-01|2016|  1|  1|
# |2016-01-01|2016|  1|  1|
# |2016-01-01|2016|  1|  1|
# |2016-01-01|2016|  1|  1|
# |2016-01-01|2016|  1|  1|
# |2016-01-01|2016|  1|  1|
# |2016-01-01|2016|  1|  1|
# |2016-01-01|2016|  1|  1|
# +----------+----+---+---+
# only showing top 20 rows

# %%
# Verificando novamente o esquema dos dados
df.printSchema()
# Out:
# root
#  |-- FL_DATE: date (nullable = true)
#  |-- OP_CARRIER: string (nullable = true)
#  |-- OP_CARRIER_FL_NUM: integer (nullable = true)
#  |-- ORIGIN: string (nullable = true)
#  |-- DEST: string (nullable = true)
#  |-- CRS_DEP_TIME: integer (nullable = true)
#  |-- DEP_TIME: double (nullable = true)
#  |-- DEP_DELAY: double (nullable = true)
#  |-- TAXI_OUT: double (nullable = true)
#  |-- WHEELS_OFF: double (nullable = true)
#  |-- WHEELS_ON: double (nullable = true)
#  |-- TAXI_IN: double (nullable = true)
#  |-- CRS_ARR_TIME: integer (nullable = true)
#  |-- ARR_TIME: double (nullable = true)
#  |-- ARR_DELAY: double (nullable = true)
#  |-- CANCELLED: double (nullable = true)
#  |-- CANCELLATION_CODE: string (nullable = true)
#  |-- DIVERTED: double (nullable = true)
#  |-- CRS_ELAPSED_TIME: double (nullable = true)
#  |-- ACTUAL_ELAPSED_TIME: double (nullable = true)
#  |-- AIR_TIME: double (nullable = true)
#  |-- DISTANCE: double (nullable = true)
#  |-- CARRIER_DELAY: double (nullable = true)
#  |-- WEATHER_DELAY: double (nullable = true)
#  |-- NAS_DELAY: double (nullable = true)
#  |-- SECURITY_DELAY: double (nullable = true)
#  |-- LATE_AIRCRAFT_DELAY: double (nullable = true)
#  |-- ano: integer (nullable = true)
#  |-- mes: integer (nullable = true)
#  |-- dia: integer (nullable = true)

# %%
# Verificando valores nulos no dataset
# Lógica: contagem quando cada linha da coluna é um valor nulo
df.select([F.count(F.when(F.isnull(c), c)).alias(c) for c in df.columns]).show(
    vertical=True
)
# Out:
# -RECORD 0----------------------
#  FL_DATE             | 0
#  OP_CARRIER          | 0
#  OP_CARRIER_FL_NUM   | 0
#  ORIGIN              | 0
#  DEST                | 0
#  CRS_DEP_TIME        | 0
#  DEP_TIME            | 63456
#  DEP_DELAY           | 63456
#  TAXI_OUT            | 65418
#  WHEELS_OFF          | 65418
#  WHEELS_ON           | 67844
#  TAXI_IN             | 67844
#  CRS_ARR_TIME        | 0
#  ARR_TIME            | 67844
#  ARR_DELAY           | 79513
#  CANCELLED           | 0
#  CANCELLATION_CODE   | 5551797
#  DIVERTED            | 0
#  CRS_ELAPSED_TIME    | 6
#  ACTUAL_ELAPSED_TIME | 79513
#  AIR_TIME            | 79513
#  DISTANCE            | 0
#  CARRIER_DELAY       | 4653419
#  WEATHER_DELAY       | 4653419
#  NAS_DELAY           | 4653419
#  SECURITY_DELAY      | 4653419
#  LATE_AIRCRAFT_DELAY | 4653419
#  ano                 | 0
#  mes                 | 0
#  dia                 | 0

# %%
# Carregando os dados das transportadoras
df_transportadoras = spark.read.csv(
    "./datasets/transportadoras.csv", header=True
)

# %%
# Visualizando as lindas e colunas do dataset
df_transportadoras.show(truncate=False)
# Out:
# +---------+---------+---------------------------+
# |IATA Code|ICAO Code|Air Carrier Name           |
# +---------+---------+---------------------------+
# |ZW       |AWI      |Air Wisconsin              |
# |AS       |ASA      |Alaska Airlines            |
# |G4       |AAY      |Allegiant Air LLC          |
# |AA       |AAL      |American Airlines          |
# |C5       |UCA      |Champlain Air              |
# |CP       |CPZ      |Compass Airlines           |
# |DL       |DAL      |Delta Air Lines            |
# |EM       |CFS      |Empire Airline             |
# |9E       |EDV      |Endeavor Air               |
# |MQ       |ENY      |Envoy Air                  |
# |EV       |ASQ      |ExpressJet Airlines        |
# |F9       |FFT      |Frontier Airlines          |
# |G7       |GJS      |GoJet Airlines             |
# |HA       |HAL      |Hawaiian Airlines          |
# |QX       |QXE      |Horizon Air                |
# |B6       |JBU      |Jetblue Airways Corporation|
# |OH       |JIA      |Jetstream Intl             |
# |YV       |ASH      |Mesa Airlines              |
# |KS       |NLA      |Penair                     |
# |PT       |PDT      |Piedmont Airlines          |
# +---------+---------+---------------------------+
# only showing top 20 rows

# %%
# Vamos verificar novamente os dado do nosso banco de dados
df.show(1, vertical=True, truncate=False)
# Out:
# -RECORD 0-------------------------
#  FL_DATE             | 2016-01-01
#  OP_CARRIER          | DL
#  OP_CARRIER_FL_NUM   | 1248
#  ORIGIN              | DTW
#  DEST                | LAX
#  CRS_DEP_TIME        | 1935
#  DEP_TIME            | 1935.0
#  DEP_DELAY           | 0.0
#  TAXI_OUT            | 23.0
#  WHEELS_OFF          | 1958.0
#  WHEELS_ON           | 2107.0
#  TAXI_IN             | 13.0
#  CRS_ARR_TIME        | 2144
#  ARR_TIME            | 2120.0
#  ARR_DELAY           | -24.0
#  CANCELLED           | 0.0
#  CANCELLATION_CODE   | NULL
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 309.0
#  ACTUAL_ELAPSED_TIME | 285.0
#  AIR_TIME            | 249.0
#  DISTANCE            | 1979.0
#  CARRIER_DELAY       | NULL
#  WEATHER_DELAY       | NULL
#  NAS_DELAY           | NULL
#  SECURITY_DELAY      | NULL
#  LATE_AIRCRAFT_DELAY | NULL
#  ano                 | 2016
#  mes                 | 1
#  dia                 | 1
# only showing top 1 row

# %%
# Renomeando os nomes das colunas para igualar os dados dos dataframes
df_transportadoras = df_transportadoras.withColumnRenamed(
    "IATA Code", "OP_CARRIER"
)

# Verificando novamente o esquema dos dados
df_transportadoras.printSchema()
# Out:
# root
#  |-- OP_CARRIER: string (nullable = true)
#  |-- ICAO Code: string (nullable = true)
#  |-- Air Carrier Name: string (nullable = true)

# %%
# Tipos de joins: inner, cross, outer,full, full_outer, left, left_outer,
# right, right_outer,left_semi, and left_anti.

# Unindo o dataframe original com o dataframe das transportados na coluna
# OP_CARRIER no tipo left (A <- B)

df = df.join(df_transportadoras, on="OP_CARRIER", how="left").drop(
    "OP_CARRIER"
)

# %%
# Verificando o schema dos dados após o junção
df.printSchema()
# Out:
# root
#  |-- FL_DATE: date (nullable = true)
#  |-- OP_CARRIER_FL_NUM: integer (nullable = true)
#  |-- ORIGIN: string (nullable = true)
#  |-- DEST: string (nullable = true)
#  |-- CRS_DEP_TIME: integer (nullable = true)
#  |-- DEP_TIME: double (nullable = true)
#  |-- DEP_DELAY: double (nullable = true)
#  |-- TAXI_OUT: double (nullable = true)
#  |-- WHEELS_OFF: double (nullable = true)
#  |-- WHEELS_ON: double (nullable = true)
#  |-- TAXI_IN: double (nullable = true)
#  |-- CRS_ARR_TIME: integer (nullable = true)
#  |-- ARR_TIME: double (nullable = true)
#  |-- ARR_DELAY: double (nullable = true)
#  |-- CANCELLED: double (nullable = true)
#  |-- CANCELLATION_CODE: string (nullable = true)
#  |-- DIVERTED: double (nullable = true)
#  |-- CRS_ELAPSED_TIME: double (nullable = true)
#  |-- ACTUAL_ELAPSED_TIME: double (nullable = true)
#  |-- AIR_TIME: double (nullable = true)
#  |-- DISTANCE: double (nullable = true)
#  |-- CARRIER_DELAY: double (nullable = true)
#  |-- WEATHER_DELAY: double (nullable = true)
#  |-- NAS_DELAY: double (nullable = true)
#  |-- SECURITY_DELAY: double (nullable = true)
#  |-- LATE_AIRCRAFT_DELAY: double (nullable = true)
#  |-- ano: integer (nullable = true)
#  |-- mes: integer (nullable = true)
#  |-- dia: integer (nullable = true)
#  |-- ICAO Code: string (nullable = true)
#  |-- Air Carrier Name: string (nullable = true)

# %%
# Verificando os nomes das transportadoras no dataframe original
df.show(vertical=True, truncate=False)
# Out:
# -RECORD 0------------------------------
#  FL_DATE             | 2016-01-01
#  OP_CARRIER_FL_NUM   | 1248
#  ORIGIN              | DTW
#  DEST                | LAX
#  CRS_DEP_TIME        | 1935
#  DEP_TIME            | 1935.0
#  DEP_DELAY           | 0.0
#  TAXI_OUT            | 23.0
#  WHEELS_OFF          | 1958.0
#  WHEELS_ON           | 2107.0
#  TAXI_IN             | 13.0
#  CRS_ARR_TIME        | 2144
#  ARR_TIME            | 2120.0
#  ARR_DELAY           | -24.0
#  CANCELLED           | 0.0
#  CANCELLATION_CODE   | NULL
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 309.0
#  ACTUAL_ELAPSED_TIME | 285.0
#  AIR_TIME            | 249.0
#  DISTANCE            | 1979.0
#  CARRIER_DELAY       | NULL
#  WEATHER_DELAY       | NULL
#  NAS_DELAY           | NULL
#  SECURITY_DELAY      | NULL
#  LATE_AIRCRAFT_DELAY | NULL
#  ano                 | 2016
#  mes                 | 1
#  dia                 | 1
#  ICAO Code           | DAL
#  Air Carrier Name    | Delta Air Lines
# -RECORD 1------------------------------
#  FL_DATE             | 2016-01-01
#  OP_CARRIER_FL_NUM   | 1251
#  ORIGIN              | ATL
#  DEST                | GRR
#  CRS_DEP_TIME        | 2125
#  DEP_TIME            | 2130.0
#  DEP_DELAY           | 5.0
#  TAXI_OUT            | 13.0
#  WHEELS_OFF          | 2143.0
#  WHEELS_ON           | 2315.0
#  TAXI_IN             | 4.0
#  CRS_ARR_TIME        | 2321
#  ARR_TIME            | 2319.0
#  ARR_DELAY           | -2.0
#  CANCELLED           | 0.0
#  CANCELLATION_CODE   | NULL
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 116.0
#  ACTUAL_ELAPSED_TIME | 109.0
#  AIR_TIME            | 92.0
#  DISTANCE            | 640.0
#  CARRIER_DELAY       | NULL
#  WEATHER_DELAY       | NULL
#  NAS_DELAY           | NULL
#  SECURITY_DELAY      | NULL
#  LATE_AIRCRAFT_DELAY | NULL
#  ano                 | 2016
#  mes                 | 1
#  dia                 | 1
#  ICAO Code           | DAL
#  Air Carrier Name    | Delta Air Lines
# -RECORD 2------------------------------
#  FL_DATE             | 2016-01-01
#  OP_CARRIER_FL_NUM   | 1254
#  ORIGIN              | LAX
#  DEST                | ATL
#  CRS_DEP_TIME        | 2255
#  DEP_TIME            | 2256.0
#  DEP_DELAY           | 1.0
#  TAXI_OUT            | 19.0
#  WHEELS_OFF          | 2315.0
#  WHEELS_ON           | 542.0
#  TAXI_IN             | 5.0
#  CRS_ARR_TIME        | 600
#  ARR_TIME            | 547.0
#  ARR_DELAY           | -13.0
#  CANCELLED           | 0.0
#  CANCELLATION_CODE   | NULL
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 245.0
#  ACTUAL_ELAPSED_TIME | 231.0
#  AIR_TIME            | 207.0
#  DISTANCE            | 1947.0
#  CARRIER_DELAY       | NULL
#  WEATHER_DELAY       | NULL
#  NAS_DELAY           | NULL
#  SECURITY_DELAY      | NULL
#  LATE_AIRCRAFT_DELAY | NULL
#  ano                 | 2016
#  mes                 | 1
#  dia                 | 1
#  ICAO Code           | DAL
#  Air Carrier Name    | Delta Air Lines
# -RECORD 3------------------------------
#  FL_DATE             | 2016-01-01
#  OP_CARRIER_FL_NUM   | 1255
#  ORIGIN              | SLC
#  DEST                | ATL
#  CRS_DEP_TIME        | 1656
#  DEP_TIME            | 1700.0
#  DEP_DELAY           | 4.0
#  TAXI_OUT            | 12.0
#  WHEELS_OFF          | 1712.0
#  WHEELS_ON           | 2205.0
#  TAXI_IN             | 8.0
#  CRS_ARR_TIME        | 2229
#  ARR_TIME            | 2213.0
#  ARR_DELAY           | -16.0
#  CANCELLED           | 0.0
#  CANCELLATION_CODE   | NULL
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 213.0
#  ACTUAL_ELAPSED_TIME | 193.0
#  AIR_TIME            | 173.0
#  DISTANCE            | 1590.0
#  CARRIER_DELAY       | NULL
#  WEATHER_DELAY       | NULL
#  NAS_DELAY           | NULL
#  SECURITY_DELAY      | NULL
#  LATE_AIRCRAFT_DELAY | NULL
#  ano                 | 2016
#  mes                 | 1
#  dia                 | 1
#  ICAO Code           | DAL
#  Air Carrier Name    | Delta Air Lines
# -RECORD 4------------------------------
#  FL_DATE             | 2016-01-01
#  OP_CARRIER_FL_NUM   | 1256
#  ORIGIN              | BZN
#  DEST                | MSP
#  CRS_DEP_TIME        | 900
#  DEP_TIME            | 1012.0
#  DEP_DELAY           | 72.0
#  TAXI_OUT            | 63.0
#  WHEELS_OFF          | 1115.0
#  WHEELS_ON           | 1416.0
#  TAXI_IN             | 4.0
#  CRS_ARR_TIME        | 1216
#  ARR_TIME            | 1420.0
#  ARR_DELAY           | 124.0
#  CANCELLED           | 0.0
#  CANCELLATION_CODE   | NULL
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 136.0
#  ACTUAL_ELAPSED_TIME | 188.0
#  AIR_TIME            | 121.0
#  DISTANCE            | 874.0
#  CARRIER_DELAY       | 72.0
#  WEATHER_DELAY       | 0.0
#  NAS_DELAY           | 52.0
#  SECURITY_DELAY      | 0.0
#  LATE_AIRCRAFT_DELAY | 0.0
#  ano                 | 2016
#  mes                 | 1
#  dia                 | 1
#  ICAO Code           | DAL
#  Air Carrier Name    | Delta Air Lines
# -RECORD 5------------------------------
#  FL_DATE             | 2016-01-01
#  OP_CARRIER_FL_NUM   | 1257
#  ORIGIN              | ATL
#  DEST                | BNA
#  CRS_DEP_TIME        | 1233
#  DEP_TIME            | 1356.0
#  DEP_DELAY           | 83.0
#  TAXI_OUT            | 22.0
#  WHEELS_OFF          | 1418.0
#  WHEELS_ON           | 1356.0
#  TAXI_IN             | 6.0
#  CRS_ARR_TIME        | 1239
#  ARR_TIME            | 1402.0
#  ARR_DELAY           | 83.0
#  CANCELLED           | 0.0
#  CANCELLATION_CODE   | NULL
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 66.0
#  ACTUAL_ELAPSED_TIME | 66.0
#  AIR_TIME            | 38.0
#  DISTANCE            | 214.0
#  CARRIER_DELAY       | 43.0
#  WEATHER_DELAY       | 0.0
#  NAS_DELAY           | 0.0
#  SECURITY_DELAY      | 0.0
#  LATE_AIRCRAFT_DELAY | 40.0
#  ano                 | 2016
#  mes                 | 1
#  dia                 | 1
#  ICAO Code           | DAL
#  Air Carrier Name    | Delta Air Lines
# -RECORD 6------------------------------
#  FL_DATE             | 2016-01-01
#  OP_CARRIER_FL_NUM   | 1257
#  ORIGIN              | BNA
#  DEST                | ATL
#  CRS_DEP_TIME        | 1320
#  DEP_TIME            | 1446.0
#  DEP_DELAY           | 86.0
#  TAXI_OUT            | 15.0
#  WHEELS_OFF          | 1501.0
#  WHEELS_ON           | 1638.0
#  TAXI_IN             | 6.0
#  CRS_ARR_TIME        | 1530
#  ARR_TIME            | 1644.0
#  ARR_DELAY           | 74.0
#  CANCELLED           | 0.0
#  CANCELLATION_CODE   | NULL
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 70.0
#  ACTUAL_ELAPSED_TIME | 58.0
#  AIR_TIME            | 37.0
#  DISTANCE            | 214.0
#  CARRIER_DELAY       | 3.0
#  WEATHER_DELAY       | 0.0
#  NAS_DELAY           | 0.0
#  SECURITY_DELAY      | 0.0
#  LATE_AIRCRAFT_DELAY | 71.0
#  ano                 | 2016
#  mes                 | 1
#  dia                 | 1
#  ICAO Code           | DAL
#  Air Carrier Name    | Delta Air Lines
# -RECORD 7------------------------------
#  FL_DATE             | 2016-01-01
#  OP_CARRIER_FL_NUM   | 1258
#  ORIGIN              | ATL
#  DEST                | JAX
#  CRS_DEP_TIME        | 945
#  DEP_TIME            | 946.0
#  DEP_DELAY           | 1.0
#  TAXI_OUT            | 19.0
#  WHEELS_OFF          | 1005.0
#  WHEELS_ON           | 1050.0
#  TAXI_IN             | 3.0
#  CRS_ARR_TIME        | 1050
#  ARR_TIME            | 1053.0
#  ARR_DELAY           | 3.0
#  CANCELLED           | 0.0
#  CANCELLATION_CODE   | NULL
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 65.0
#  ACTUAL_ELAPSED_TIME | 67.0
#  AIR_TIME            | 45.0
#  DISTANCE            | 270.0
#  CARRIER_DELAY       | NULL
#  WEATHER_DELAY       | NULL
#  NAS_DELAY           | NULL
#  SECURITY_DELAY      | NULL
#  LATE_AIRCRAFT_DELAY | NULL
#  ano                 | 2016
#  mes                 | 1
#  dia                 | 1
#  ICAO Code           | DAL
#  Air Carrier Name    | Delta Air Lines
# -RECORD 8------------------------------
#  FL_DATE             | 2016-01-01
#  OP_CARRIER_FL_NUM   | 1258
#  ORIGIN              | JAX
#  DEST                | ATL
#  CRS_DEP_TIME        | 1145
#  DEP_TIME            | 1144.0
#  DEP_DELAY           | -1.0
#  TAXI_OUT            | 12.0
#  WHEELS_OFF          | 1156.0
#  WHEELS_ON           | 1239.0
#  TAXI_IN             | 8.0
#  CRS_ARR_TIME        | 1302
#  ARR_TIME            | 1247.0
#  ARR_DELAY           | -15.0
#  CANCELLED           | 0.0
#  CANCELLATION_CODE   | NULL
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 77.0
#  ACTUAL_ELAPSED_TIME | 63.0
#  AIR_TIME            | 43.0
#  DISTANCE            | 270.0
#  CARRIER_DELAY       | NULL
#  WEATHER_DELAY       | NULL
#  NAS_DELAY           | NULL
#  SECURITY_DELAY      | NULL
#  LATE_AIRCRAFT_DELAY | NULL
#  ano                 | 2016
#  mes                 | 1
#  dia                 | 1
#  ICAO Code           | DAL
#  Air Carrier Name    | Delta Air Lines
# -RECORD 9------------------------------
#  FL_DATE             | 2016-01-01
#  OP_CARRIER_FL_NUM   | 1259
#  ORIGIN              | ATL
#  DEST                | OKC
#  CRS_DEP_TIME        | 2110
#  DEP_TIME            | 2107.0
#  DEP_DELAY           | -3.0
#  TAXI_OUT            | 16.0
#  WHEELS_OFF          | 2123.0
#  WHEELS_ON           | 2219.0
#  TAXI_IN             | 5.0
#  CRS_ARR_TIME        | 2236
#  ARR_TIME            | 2224.0
#  ARR_DELAY           | -12.0
#  CANCELLED           | 0.0
#  CANCELLATION_CODE   | NULL
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 146.0
#  ACTUAL_ELAPSED_TIME | 137.0
#  AIR_TIME            | 116.0
#  DISTANCE            | 761.0
#  CARRIER_DELAY       | NULL
#  WEATHER_DELAY       | NULL
#  NAS_DELAY           | NULL
#  SECURITY_DELAY      | NULL
#  LATE_AIRCRAFT_DELAY | NULL
#  ano                 | 2016
#  mes                 | 1
#  dia                 | 1
#  ICAO Code           | DAL
#  Air Carrier Name    | Delta Air Lines
# -RECORD 10-----------------------------
#  FL_DATE             | 2016-01-01
#  OP_CARRIER_FL_NUM   | 1260
#  ORIGIN              | MSP
#  DEST                | SMF
#  CRS_DEP_TIME        | 1115
#  DEP_TIME            | 1113.0
#  DEP_DELAY           | -2.0
#  TAXI_OUT            | 12.0
#  WHEELS_OFF          | 1125.0
#  WHEELS_ON           | 1232.0
#  TAXI_IN             | 4.0
#  CRS_ARR_TIME        | 1309
#  ARR_TIME            | 1236.0
#  ARR_DELAY           | -33.0
#  CANCELLED           | 0.0
#  CANCELLATION_CODE   | NULL
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 234.0
#  ACTUAL_ELAPSED_TIME | 203.0
#  AIR_TIME            | 187.0
#  DISTANCE            | 1517.0
#  CARRIER_DELAY       | NULL
#  WEATHER_DELAY       | NULL
#  NAS_DELAY           | NULL
#  SECURITY_DELAY      | NULL
#  LATE_AIRCRAFT_DELAY | NULL
#  ano                 | 2016
#  mes                 | 1
#  dia                 | 1
#  ICAO Code           | DAL
#  Air Carrier Name    | Delta Air Lines
# -RECORD 11-----------------------------
#  FL_DATE             | 2016-01-01
#  OP_CARRIER_FL_NUM   | 1262
#  ORIGIN              | LAX
#  DEST                | JFK
#  CRS_DEP_TIME        | 2255
#  DEP_TIME            | 2248.0
#  DEP_DELAY           | -7.0
#  TAXI_OUT            | 23.0
#  WHEELS_OFF          | 2311.0
#  WHEELS_ON           | 650.0
#  TAXI_IN             | 11.0
#  CRS_ARR_TIME        | 715
#  ARR_TIME            | 701.0
#  ARR_DELAY           | -14.0
#  CANCELLED           | 0.0
#  CANCELLATION_CODE   | NULL
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 320.0
#  ACTUAL_ELAPSED_TIME | 313.0
#  AIR_TIME            | 279.0
#  DISTANCE            | 2475.0
#  CARRIER_DELAY       | NULL
#  WEATHER_DELAY       | NULL
#  NAS_DELAY           | NULL
#  SECURITY_DELAY      | NULL
#  LATE_AIRCRAFT_DELAY | NULL
#  ano                 | 2016
#  mes                 | 1
#  dia                 | 1
#  ICAO Code           | DAL
#  Air Carrier Name    | Delta Air Lines
# -RECORD 12-----------------------------
#  FL_DATE             | 2016-01-01
#  OP_CARRIER_FL_NUM   | 1263
#  ORIGIN              | ATL
#  DEST                | MDT
#  CRS_DEP_TIME        | 1510
#  DEP_TIME            | 1509.0
#  DEP_DELAY           | -1.0
#  TAXI_OUT            | 17.0
#  WHEELS_OFF          | 1526.0
#  WHEELS_ON           | 1646.0
#  TAXI_IN             | 5.0
#  CRS_ARR_TIME        | 1702
#  ARR_TIME            | 1651.0
#  ARR_DELAY           | -11.0
#  CANCELLED           | 0.0
#  CANCELLATION_CODE   | NULL
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 112.0
#  ACTUAL_ELAPSED_TIME | 102.0
#  AIR_TIME            | 80.0
#  DISTANCE            | 620.0
#  CARRIER_DELAY       | NULL
#  WEATHER_DELAY       | NULL
#  NAS_DELAY           | NULL
#  SECURITY_DELAY      | NULL
#  LATE_AIRCRAFT_DELAY | NULL
#  ano                 | 2016
#  mes                 | 1
#  dia                 | 1
#  ICAO Code           | DAL
#  Air Carrier Name    | Delta Air Lines
# -RECORD 13-----------------------------
#  FL_DATE             | 2016-01-01
#  OP_CARRIER_FL_NUM   | 1263
#  ORIGIN              | MDT
#  DEST                | ATL
#  CRS_DEP_TIME        | 1737
#  DEP_TIME            | 1727.0
#  DEP_DELAY           | -10.0
#  TAXI_OUT            | 11.0
#  WHEELS_OFF          | 1738.0
#  WHEELS_ON           | 1923.0
#  TAXI_IN             | 11.0
#  CRS_ARR_TIME        | 1949
#  ARR_TIME            | 1934.0
#  ARR_DELAY           | -15.0
#  CANCELLED           | 0.0
#  CANCELLATION_CODE   | NULL
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 132.0
#  ACTUAL_ELAPSED_TIME | 127.0
#  AIR_TIME            | 105.0
#  DISTANCE            | 620.0
#  CARRIER_DELAY       | NULL
#  WEATHER_DELAY       | NULL
#  NAS_DELAY           | NULL
#  SECURITY_DELAY      | NULL
#  LATE_AIRCRAFT_DELAY | NULL
#  ano                 | 2016
#  mes                 | 1
#  dia                 | 1
#  ICAO Code           | DAL
#  Air Carrier Name    | Delta Air Lines
# -RECORD 14-----------------------------
#  FL_DATE             | 2016-01-01
#  OP_CARRIER_FL_NUM   | 1264
#  ORIGIN              | SLC
#  DEST                | JFK
#  CRS_DEP_TIME        | 2345
#  DEP_TIME            | 2341.0
#  DEP_DELAY           | -4.0
#  TAXI_OUT            | 25.0
#  WHEELS_OFF          | 6.0
#  WHEELS_ON           | 602.0
#  TAXI_IN             | 11.0
#  CRS_ARR_TIME        | 607
#  ARR_TIME            | 613.0
#  ARR_DELAY           | 6.0
#  CANCELLED           | 0.0
#  CANCELLATION_CODE   | NULL
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 262.0
#  ACTUAL_ELAPSED_TIME | 272.0
#  AIR_TIME            | 236.0
#  DISTANCE            | 1990.0
#  CARRIER_DELAY       | NULL
#  WEATHER_DELAY       | NULL
#  NAS_DELAY           | NULL
#  SECURITY_DELAY      | NULL
#  LATE_AIRCRAFT_DELAY | NULL
#  ano                 | 2016
#  mes                 | 1
#  dia                 | 1
#  ICAO Code           | DAL
#  Air Carrier Name    | Delta Air Lines
# -RECORD 15-----------------------------
#  FL_DATE             | 2016-01-01
#  OP_CARRIER_FL_NUM   | 1265
#  ORIGIN              | SAV
#  DEST                | ATL
#  CRS_DEP_TIME        | 1408
#  DEP_TIME            | 1403.0
#  DEP_DELAY           | -5.0
#  TAXI_OUT            | 15.0
#  WHEELS_OFF          | 1418.0
#  WHEELS_ON           | 1459.0
#  TAXI_IN             | 6.0
#  CRS_ARR_TIME        | 1523
#  ARR_TIME            | 1505.0
#  ARR_DELAY           | -18.0
#  CANCELLED           | 0.0
#  CANCELLATION_CODE   | NULL
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 75.0
#  ACTUAL_ELAPSED_TIME | 62.0
#  AIR_TIME            | 41.0
#  DISTANCE            | 214.0
#  CARRIER_DELAY       | NULL
#  WEATHER_DELAY       | NULL
#  NAS_DELAY           | NULL
#  SECURITY_DELAY      | NULL
#  LATE_AIRCRAFT_DELAY | NULL
#  ano                 | 2016
#  mes                 | 1
#  dia                 | 1
#  ICAO Code           | DAL
#  Air Carrier Name    | Delta Air Lines
# -RECORD 16-----------------------------
#  FL_DATE             | 2016-01-01
#  OP_CARRIER_FL_NUM   | 1266
#  ORIGIN              | BUF
#  DEST                | ATL
#  CRS_DEP_TIME        | 615
#  DEP_TIME            | 612.0
#  DEP_DELAY           | -3.0
#  TAXI_OUT            | 38.0
#  WHEELS_OFF          | 650.0
#  WHEELS_ON           | 844.0
#  TAXI_IN             | 5.0
#  CRS_ARR_TIME        | 843
#  ARR_TIME            | 849.0
#  ARR_DELAY           | 6.0
#  CANCELLED           | 0.0
#  CANCELLATION_CODE   | NULL
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 148.0
#  ACTUAL_ELAPSED_TIME | 157.0
#  AIR_TIME            | 114.0
#  DISTANCE            | 712.0
#  CARRIER_DELAY       | NULL
#  WEATHER_DELAY       | NULL
#  NAS_DELAY           | NULL
#  SECURITY_DELAY      | NULL
#  LATE_AIRCRAFT_DELAY | NULL
#  ano                 | 2016
#  mes                 | 1
#  dia                 | 1
#  ICAO Code           | DAL
#  Air Carrier Name    | Delta Air Lines
# -RECORD 17-----------------------------
#  FL_DATE             | 2016-01-01
#  OP_CARRIER_FL_NUM   | 1269
#  ORIGIN              | LGA
#  DEST                | MIA
#  CRS_DEP_TIME        | 1100
#  DEP_TIME            | 1100.0
#  DEP_DELAY           | 0.0
#  TAXI_OUT            | 15.0
#  WHEELS_OFF          | 1115.0
#  WHEELS_ON           | 1402.0
#  TAXI_IN             | 4.0
#  CRS_ARR_TIME        | 1432
#  ARR_TIME            | 1406.0
#  ARR_DELAY           | -26.0
#  CANCELLED           | 0.0
#  CANCELLATION_CODE   | NULL
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 212.0
#  ACTUAL_ELAPSED_TIME | 186.0
#  AIR_TIME            | 167.0
#  DISTANCE            | 1096.0
#  CARRIER_DELAY       | NULL
#  WEATHER_DELAY       | NULL
#  NAS_DELAY           | NULL
#  SECURITY_DELAY      | NULL
#  LATE_AIRCRAFT_DELAY | NULL
#  ano                 | 2016
#  mes                 | 1
#  dia                 | 1
#  ICAO Code           | DAL
#  Air Carrier Name    | Delta Air Lines
# -RECORD 18-----------------------------
#  FL_DATE             | 2016-01-01
#  OP_CARRIER_FL_NUM   | 1270
#  ORIGIN              | ATL
#  DEST                | PNS
#  CRS_DEP_TIME        | 1340
#  DEP_TIME            | 1337.0
#  DEP_DELAY           | -3.0
#  TAXI_OUT            | 11.0
#  WHEELS_OFF          | 1348.0
#  WHEELS_ON           | 1339.0
#  TAXI_IN             | 3.0
#  CRS_ARR_TIME        | 1352
#  ARR_TIME            | 1342.0
#  ARR_DELAY           | -10.0
#  CANCELLED           | 0.0
#  CANCELLATION_CODE   | NULL
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 72.0
#  ACTUAL_ELAPSED_TIME | 65.0
#  AIR_TIME            | 51.0
#  DISTANCE            | 271.0
#  CARRIER_DELAY       | NULL
#  WEATHER_DELAY       | NULL
#  NAS_DELAY           | NULL
#  SECURITY_DELAY      | NULL
#  LATE_AIRCRAFT_DELAY | NULL
#  ano                 | 2016
#  mes                 | 1
#  dia                 | 1
#  ICAO Code           | DAL
#  Air Carrier Name    | Delta Air Lines
# -RECORD 19-----------------------------
#  FL_DATE             | 2016-01-01
#  OP_CARRIER_FL_NUM   | 1270
#  ORIGIN              | PNS
#  DEST                | ATL
#  CRS_DEP_TIME        | 1435
#  DEP_TIME            | 1431.0
#  DEP_DELAY           | -4.0
#  TAXI_OUT            | 10.0
#  WHEELS_OFF          | 1441.0
#  WHEELS_ON           | 1622.0
#  TAXI_IN             | 6.0
#  CRS_ARR_TIME        | 1648
#  ARR_TIME            | 1628.0
#  ARR_DELAY           | -20.0
#  CANCELLED           | 0.0
#  CANCELLATION_CODE   | NULL
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 73.0
#  ACTUAL_ELAPSED_TIME | 57.0
#  AIR_TIME            | 41.0
#  DISTANCE            | 271.0
#  CARRIER_DELAY       | NULL
#  WEATHER_DELAY       | NULL
#  NAS_DELAY           | NULL
#  SECURITY_DELAY      | NULL
#  LATE_AIRCRAFT_DELAY | NULL
#  ano                 | 2016
#  mes                 | 1
#  dia                 | 1
#  ICAO Code           | DAL
#  Air Carrier Name    | Delta Air Lines
# only showing top 20 rows

# %% [markdown]
# ### Agrupamento e Resumo dos Dados

# %%
# Fluxo de funções: groupby -> agg

# Agrupando por mes e agregando pela média do atraso na chegada
df.groupby("mes").agg(F.avg("ARR_DELAY").alias("media_atraso_chegada")).show()
# Out:
# +---+--------------------+
# |mes|media_atraso_chegada|
# +---+--------------------+
# |  1|   1.533653513286468|
# |  2|  0.6652991970622235|
# |  3|  3.1459138871633643|
# |  4|  0.6968198081024388|
# |  5|  2.2490057812950184|
# |  6|   7.154742200301092|
# |  7|  10.384150586932357|
# |  8|   8.013417284908106|
# |  9| 0.49918242523610235|
# | 10| -0.2230462516524559|
# | 11| -1.8610726847860712|
# | 12|   8.664734017499983|
# +---+--------------------+

# %%
# Agrupando e resumindo múltiplas colunas
df_agrupado = df.groupby("mes").agg(
    # média do atraso na chegada
    F.avg("ARR_DELAY").alias("media_atraso_chegada"),
    # soma de voos cancelados
    F.sum("CANCELLED").alias("voos_cancelados"),
    # contagem da quantidade de voos (linhas)
    F.count(F.lit(1)).alias("quantidade_de_voos"),
)

# Visualizar o dataset agrupado
df_agrupado.show()
# Out:
# +---+--------------------+---------------+------------------+
# |mes|media_atraso_chegada|voos_cancelados|quantidade_de_voos|
# +---+--------------------+---------------+------------------+
# |  1|   1.533653513286468|        11665.0|            445827|
# |  2|  0.6652991970622235|         6823.0|            423889|
# |  3|  3.1459138871633643|         4733.0|            479122|
# |  4|  0.6968198081024388|         4109.0|            461630|
# |  5|  2.2490057812950184|         2509.0|            479358|
# |  6|   7.154742200301092|         4982.0|            487637|
# |  7|  10.384150586932357|         9309.0|            502457|
# |  8|   8.013417284908106|         6893.0|            498347|
# |  9| 0.49918242523610235|         1517.0|            454878|
# | 10| -0.2230462516524559|         4547.0|            472626|
# | 11| -1.8610726847860712|         1310.0|            450938|
# | 12|   8.664734017499983|         7464.0|            460949|
# +---+--------------------+---------------+------------------+

# %%
# Criando uma nova coluna com a porcentagem dos voos
df_agrupado = df_agrupado.withColumn(
    "porcentagem_voos_cancelados",
    # fórmula: (voos_cancelados/quantidade_de_voos)*100
    (df_agrupado["voos_cancelados"] / df_agrupado["quantidade_de_voos"]) * 100,
)

# Visualizar o dataset agrupado
df_agrupado.show()
# Out:
# +---+--------------------+---------------+------------------+---------------------------+
# |mes|media_atraso_chegada|voos_cancelados|quantidade_de_voos|porcentagem_voos_cancelados|
# +---+--------------------+---------------+------------------+---------------------------+
# |  1|   1.533653513286468|        11665.0|            445827|         2.6164857669006136|
# |  2|  0.6652991970622235|         6823.0|            423889|           1.60961949944443|
# |  3|  3.1459138871633643|         4733.0|            479122|         0.9878486064092236|
# |  4|  0.6968198081024388|         4109.0|            461630|          0.890106795485562|
# |  5|  2.2490057812950184|         2509.0|            479358|         0.5234083920577105|
# |  6|   7.154742200301092|         4982.0|            487637|          1.021661604841306|
# |  7|  10.384150586932357|         9309.0|            502457|         1.8526958525804198|
# |  8|   8.013417284908106|         6893.0|            498347|         1.3831727691748923|
# |  9| 0.49918242523610235|         1517.0|            454878|        0.33349601431592646|
# | 10| -0.2230462516524559|         4547.0|            472626|         0.9620714899307276|
# | 11| -1.8610726847860712|         1310.0|            450938|        0.29050556839299413|
# | 12|   8.664734017499983|         7464.0|            460949|         1.6192680752100557|
# +---+--------------------+---------------+------------------+---------------------------+

# %%
# Filtrando apenas os dados dos voos cancelados
df_cancelados = df.where(df["CANCELLED"] == 1)

# Mostrando os dados de forma vertical
df_cancelados.show(1, vertical=True)
# Out:
# -RECORD 0------------------------------
#  FL_DATE             | 2016-01-01
#  OP_CARRIER_FL_NUM   | 29
#  ORIGIN              | ORD
#  DEST                | SEA
#  CRS_DEP_TIME        | 1530
#  DEP_TIME            | NULL
#  DEP_DELAY           | NULL
#  TAXI_OUT            | NULL
#  WHEELS_OFF          | NULL
#  WHEELS_ON           | NULL
#  TAXI_IN             | NULL
#  CRS_ARR_TIME        | 1815
#  ARR_TIME            | NULL
#  ARR_DELAY           | NULL
#  CANCELLED           | 1.0
#  CANCELLATION_CODE   | A
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 285.0
#  ACTUAL_ELAPSED_TIME | NULL
#  AIR_TIME            | NULL
#  DISTANCE            | 1721.0
#  CARRIER_DELAY       | NULL
#  WEATHER_DELAY       | NULL
#  NAS_DELAY           | NULL
#  SECURITY_DELAY      | NULL
#  LATE_AIRCRAFT_DELAY | NULL
#  ano                 | 2016
#  mes                 | 1
#  dia                 | 1
#  ICAO Code           | ASA
#  Air Carrier Name    | Alaska Airlines
# only showing top 1 row

# %%
# Códigos de cancelamento

# A = Por transportadora
# B = Devido às condições climáticas
# C = Pelo sistema nacional de transporte aéreo
# D = Por razões de segurança

# Trocando os dados pelas informações reais
df_cancelados = df_cancelados.withColumn(
    "CANCELLATION_CODE",
    F.when(
        df_cancelados["CANCELLATION_CODE"] == "A", "Por transportadora"
    ).otherwise(df_cancelados["CANCELLATION_CODE"]),
)
df_cancelados = df_cancelados.withColumn(
    "CANCELLATION_CODE",
    F.when(
        df_cancelados["CANCELLATION_CODE"] == "B",
        "Devido às condições climáticas",
    ).otherwise(df_cancelados["CANCELLATION_CODE"]),
)
df_cancelados = df_cancelados.withColumn(
    "CANCELLATION_CODE",
    F.when(
        df_cancelados["CANCELLATION_CODE"] == "C",
        "Pelo sistema nacional de transporte aéreo",
    ).otherwise(df_cancelados["CANCELLATION_CODE"]),
)
df_cancelados = df_cancelados.withColumn(
    "CANCELLATION_CODE",
    F.when(
        df_cancelados["CANCELLATION_CODE"] == "D", "Por razões de segurança"
    ).otherwise(df_cancelados["CANCELLATION_CODE"]),
)

# %%
# Verificando os dados alterados
df_cancelados.show(vertical=True)
# Out:
# -RECORD 0-----------------------------------
#  FL_DATE             | 2016-01-01
#  OP_CARRIER_FL_NUM   | 29
#  ORIGIN              | ORD
#  DEST                | SEA
#  CRS_DEP_TIME        | 1530
#  DEP_TIME            | NULL
#  DEP_DELAY           | NULL
#  TAXI_OUT            | NULL
#  WHEELS_OFF          | NULL
#  WHEELS_ON           | NULL
#  TAXI_IN             | NULL
#  CRS_ARR_TIME        | 1815
#  ARR_TIME            | NULL
#  ARR_DELAY           | NULL
#  CANCELLED           | 1.0
#  CANCELLATION_CODE   | Por transportadora
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 285.0
#  ACTUAL_ELAPSED_TIME | NULL
#  AIR_TIME            | NULL
#  DISTANCE            | 1721.0
#  CARRIER_DELAY       | NULL
#  WEATHER_DELAY       | NULL
#  NAS_DELAY           | NULL
#  SECURITY_DELAY      | NULL
#  LATE_AIRCRAFT_DELAY | NULL
#  ano                 | 2016
#  mes                 | 1
#  dia                 | 1
#  ICAO Code           | ASA
#  Air Carrier Name    | Alaska Airlines
# -RECORD 1-----------------------------------
#  FL_DATE             | 2016-01-01
#  OP_CARRIER_FL_NUM   | 40
#  ORIGIN              | ADQ
#  DEST                | ANC
#  CRS_DEP_TIME        | 1720
#  DEP_TIME            | NULL
#  DEP_DELAY           | NULL
#  TAXI_OUT            | NULL
#  WHEELS_OFF          | NULL
#  WHEELS_ON           | NULL
#  TAXI_IN             | NULL
#  CRS_ARR_TIME        | 1809
#  ARR_TIME            | NULL
#  ARR_DELAY           | NULL
#  CANCELLED           | 1.0
#  CANCELLATION_CODE   | Devido às condiçõ...
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 49.0
#  ACTUAL_ELAPSED_TIME | NULL
#  AIR_TIME            | NULL
#  DISTANCE            | 253.0
#  CARRIER_DELAY       | NULL
#  WEATHER_DELAY       | NULL
#  NAS_DELAY           | NULL
#  SECURITY_DELAY      | NULL
#  LATE_AIRCRAFT_DELAY | NULL
#  ano                 | 2016
#  mes                 | 1
#  dia                 | 1
#  ICAO Code           | ASA
#  Air Carrier Name    | Alaska Airlines
# -RECORD 2-----------------------------------
#  FL_DATE             | 2016-01-01
#  OP_CARRIER_FL_NUM   | 49
#  ORIGIN              | ANC
#  DEST                | ADQ
#  CRS_DEP_TIME        | 1530
#  DEP_TIME            | NULL
#  DEP_DELAY           | NULL
#  TAXI_OUT            | NULL
#  WHEELS_OFF          | NULL
#  WHEELS_ON           | NULL
#  TAXI_IN             | NULL
#  CRS_ARR_TIME        | 1628
#  ARR_TIME            | NULL
#  ARR_DELAY           | NULL
#  CANCELLED           | 1.0
#  CANCELLATION_CODE   | Devido às condiçõ...
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 58.0
#  ACTUAL_ELAPSED_TIME | NULL
#  AIR_TIME            | NULL
#  DISTANCE            | 253.0
#  CARRIER_DELAY       | NULL
#  WEATHER_DELAY       | NULL
#  NAS_DELAY           | NULL
#  SECURITY_DELAY      | NULL
#  LATE_AIRCRAFT_DELAY | NULL
#  ano                 | 2016
#  mes                 | 1
#  dia                 | 1
#  ICAO Code           | ASA
#  Air Carrier Name    | Alaska Airlines
# -RECORD 3-----------------------------------
#  FL_DATE             | 2016-01-01
#  OP_CARRIER_FL_NUM   | 3274
#  ORIGIN              | ERI
#  DEST                | ORD
#  CRS_DEP_TIME        | 1655
#  DEP_TIME            | NULL
#  DEP_DELAY           | NULL
#  TAXI_OUT            | NULL
#  WHEELS_OFF          | NULL
#  WHEELS_ON           | NULL
#  TAXI_IN             | NULL
#  CRS_ARR_TIME        | 1739
#  ARR_TIME            | NULL
#  ARR_DELAY           | NULL
#  CANCELLED           | 1.0
#  CANCELLATION_CODE   | Devido às condiçõ...
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 104.0
#  ACTUAL_ELAPSED_TIME | NULL
#  AIR_TIME            | NULL
#  DISTANCE            | 398.0
#  CARRIER_DELAY       | NULL
#  WEATHER_DELAY       | NULL
#  NAS_DELAY           | NULL
#  SECURITY_DELAY      | NULL
#  LATE_AIRCRAFT_DELAY | NULL
#  ano                 | 2016
#  mes                 | 1
#  dia                 | 1
#  ICAO Code           | ASQ
#  Air Carrier Name    | ExpressJet Airlines
# -RECORD 4-----------------------------------
#  FL_DATE             | 2016-01-01
#  OP_CARRIER_FL_NUM   | 3815
#  ORIGIN              | IAH
#  DEST                | OKC
#  CRS_DEP_TIME        | 1445
#  DEP_TIME            | NULL
#  DEP_DELAY           | NULL
#  TAXI_OUT            | NULL
#  WHEELS_OFF          | NULL
#  WHEELS_ON           | NULL
#  TAXI_IN             | NULL
#  CRS_ARR_TIME        | 1615
#  ARR_TIME            | NULL
#  ARR_DELAY           | NULL
#  CANCELLED           | 1.0
#  CANCELLATION_CODE   | Pelo sistema naci...
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 90.0
#  ACTUAL_ELAPSED_TIME | NULL
#  AIR_TIME            | NULL
#  DISTANCE            | 395.0
#  CARRIER_DELAY       | NULL
#  WEATHER_DELAY       | NULL
#  NAS_DELAY           | NULL
#  SECURITY_DELAY      | NULL
#  LATE_AIRCRAFT_DELAY | NULL
#  ano                 | 2016
#  mes                 | 1
#  dia                 | 1
#  ICAO Code           | ASQ
#  Air Carrier Name    | ExpressJet Airlines
# -RECORD 5-----------------------------------
#  FL_DATE             | 2016-01-01
#  OP_CARRIER_FL_NUM   | 4156
#  ORIGIN              | IAH
#  DEST                | AMA
#  CRS_DEP_TIME        | 2125
#  DEP_TIME            | NULL
#  DEP_DELAY           | NULL
#  TAXI_OUT            | NULL
#  WHEELS_OFF          | NULL
#  WHEELS_ON           | NULL
#  TAXI_IN             | NULL
#  CRS_ARR_TIME        | 2316
#  ARR_TIME            | NULL
#  ARR_DELAY           | NULL
#  CANCELLED           | 1.0
#  CANCELLATION_CODE   | Por transportadora
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 111.0
#  ACTUAL_ELAPSED_TIME | NULL
#  AIR_TIME            | NULL
#  DISTANCE            | 517.0
#  CARRIER_DELAY       | NULL
#  WEATHER_DELAY       | NULL
#  NAS_DELAY           | NULL
#  SECURITY_DELAY      | NULL
#  LATE_AIRCRAFT_DELAY | NULL
#  ano                 | 2016
#  mes                 | 1
#  dia                 | 1
#  ICAO Code           | ASQ
#  Air Carrier Name    | ExpressJet Airlines
# -RECORD 6-----------------------------------
#  FL_DATE             | 2016-01-01
#  OP_CARRIER_FL_NUM   | 4231
#  ORIGIN              | IAH
#  DEST                | BTR
#  CRS_DEP_TIME        | 2121
#  DEP_TIME            | NULL
#  DEP_DELAY           | NULL
#  TAXI_OUT            | NULL
#  WHEELS_OFF          | NULL
#  WHEELS_ON           | NULL
#  TAXI_IN             | NULL
#  CRS_ARR_TIME        | 2226
#  ARR_TIME            | NULL
#  ARR_DELAY           | NULL
#  CANCELLED           | 1.0
#  CANCELLATION_CODE   | Pelo sistema naci...
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 65.0
#  ACTUAL_ELAPSED_TIME | NULL
#  AIR_TIME            | NULL
#  DISTANCE            | 253.0
#  CARRIER_DELAY       | NULL
#  WEATHER_DELAY       | NULL
#  NAS_DELAY           | NULL
#  SECURITY_DELAY      | NULL
#  LATE_AIRCRAFT_DELAY | NULL
#  ano                 | 2016
#  mes                 | 1
#  dia                 | 1
#  ICAO Code           | ASQ
#  Air Carrier Name    | ExpressJet Airlines
# -RECORD 7-----------------------------------
#  FL_DATE             | 2016-01-01
#  OP_CARRIER_FL_NUM   | 4459
#  ORIGIN              | ORF
#  DEST                | EWR
#  CRS_DEP_TIME        | 1725
#  DEP_TIME            | NULL
#  DEP_DELAY           | NULL
#  TAXI_OUT            | NULL
#  WHEELS_OFF          | NULL
#  WHEELS_ON           | NULL
#  TAXI_IN             | NULL
#  CRS_ARR_TIME        | 1855
#  ARR_TIME            | NULL
#  ARR_DELAY           | NULL
#  CANCELLED           | 1.0
#  CANCELLATION_CODE   | Por transportadora
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 90.0
#  ACTUAL_ELAPSED_TIME | NULL
#  AIR_TIME            | NULL
#  DISTANCE            | 284.0
#  CARRIER_DELAY       | NULL
#  WEATHER_DELAY       | NULL
#  NAS_DELAY           | NULL
#  SECURITY_DELAY      | NULL
#  LATE_AIRCRAFT_DELAY | NULL
#  ano                 | 2016
#  mes                 | 1
#  dia                 | 1
#  ICAO Code           | ASQ
#  Air Carrier Name    | ExpressJet Airlines
# -RECORD 8-----------------------------------
#  FL_DATE             | 2016-01-01
#  OP_CARRIER_FL_NUM   | 4285
#  ORIGIN              | IAH
#  DEST                | GSP
#  CRS_DEP_TIME        | 1957
#  DEP_TIME            | NULL
#  DEP_DELAY           | NULL
#  TAXI_OUT            | NULL
#  WHEELS_OFF          | NULL
#  WHEELS_ON           | NULL
#  TAXI_IN             | NULL
#  CRS_ARR_TIME        | 2307
#  ARR_TIME            | NULL
#  ARR_DELAY           | NULL
#  CANCELLED           | 1.0
#  CANCELLATION_CODE   | Pelo sistema naci...
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 130.0
#  ACTUAL_ELAPSED_TIME | NULL
#  AIR_TIME            | NULL
#  DISTANCE            | 837.0
#  CARRIER_DELAY       | NULL
#  WEATHER_DELAY       | NULL
#  NAS_DELAY           | NULL
#  SECURITY_DELAY      | NULL
#  LATE_AIRCRAFT_DELAY | NULL
#  ano                 | 2016
#  mes                 | 1
#  dia                 | 1
#  ICAO Code           | ASQ
#  Air Carrier Name    | ExpressJet Airlines
# -RECORD 9-----------------------------------
#  FL_DATE             | 2016-01-01
#  OP_CARRIER_FL_NUM   | 4438
#  ORIGIN              | HOB
#  DEST                | IAH
#  CRS_DEP_TIME        | 640
#  DEP_TIME            | NULL
#  DEP_DELAY           | NULL
#  TAXI_OUT            | NULL
#  WHEELS_OFF          | NULL
#  WHEELS_ON           | NULL
#  TAXI_IN             | NULL
#  CRS_ARR_TIME        | 921
#  ARR_TIME            | NULL
#  ARR_DELAY           | NULL
#  CANCELLED           | 1.0
#  CANCELLATION_CODE   | Devido às condiçõ...
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 101.0
#  ACTUAL_ELAPSED_TIME | NULL
#  AIR_TIME            | NULL
#  DISTANCE            | 501.0
#  CARRIER_DELAY       | NULL
#  WEATHER_DELAY       | NULL
#  NAS_DELAY           | NULL
#  SECURITY_DELAY      | NULL
#  LATE_AIRCRAFT_DELAY | NULL
#  ano                 | 2016
#  mes                 | 1
#  dia                 | 1
#  ICAO Code           | ASQ
#  Air Carrier Name    | ExpressJet Airlines
# -RECORD 10----------------------------------
#  FL_DATE             | 2016-01-01
#  OP_CARRIER_FL_NUM   | 4535
#  ORIGIN              | HOB
#  DEST                | IAH
#  CRS_DEP_TIME        | 1212
#  DEP_TIME            | NULL
#  DEP_DELAY           | NULL
#  TAXI_OUT            | NULL
#  WHEELS_OFF          | NULL
#  WHEELS_ON           | NULL
#  TAXI_IN             | NULL
#  CRS_ARR_TIME        | 1450
#  ARR_TIME            | NULL
#  ARR_DELAY           | NULL
#  CANCELLED           | 1.0
#  CANCELLATION_CODE   | Devido às condiçõ...
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 98.0
#  ACTUAL_ELAPSED_TIME | NULL
#  AIR_TIME            | NULL
#  DISTANCE            | 501.0
#  CARRIER_DELAY       | NULL
#  WEATHER_DELAY       | NULL
#  NAS_DELAY           | NULL
#  SECURITY_DELAY      | NULL
#  LATE_AIRCRAFT_DELAY | NULL
#  ano                 | 2016
#  mes                 | 1
#  dia                 | 1
#  ICAO Code           | ASQ
#  Air Carrier Name    | ExpressJet Airlines
# -RECORD 11----------------------------------
#  FL_DATE             | 2016-01-01
#  OP_CARRIER_FL_NUM   | 4663
#  ORIGIN              | OKC
#  DEST                | IAH
#  CRS_DEP_TIME        | 1645
#  DEP_TIME            | NULL
#  DEP_DELAY           | NULL
#  TAXI_OUT            | NULL
#  WHEELS_OFF          | NULL
#  WHEELS_ON           | NULL
#  TAXI_IN             | NULL
#  CRS_ARR_TIME        | 1818
#  ARR_TIME            | NULL
#  ARR_DELAY           | NULL
#  CANCELLED           | 1.0
#  CANCELLATION_CODE   | Pelo sistema naci...
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 93.0
#  ACTUAL_ELAPSED_TIME | NULL
#  AIR_TIME            | NULL
#  DISTANCE            | 395.0
#  CARRIER_DELAY       | NULL
#  WEATHER_DELAY       | NULL
#  NAS_DELAY           | NULL
#  SECURITY_DELAY      | NULL
#  LATE_AIRCRAFT_DELAY | NULL
#  ano                 | 2016
#  mes                 | 1
#  dia                 | 1
#  ICAO Code           | ASQ
#  Air Carrier Name    | ExpressJet Airlines
# -RECORD 12----------------------------------
#  FL_DATE             | 2016-01-01
#  OP_CARRIER_FL_NUM   | 4194
#  ORIGIN              | MCI
#  DEST                | IAH
#  CRS_DEP_TIME        | 1430
#  DEP_TIME            | NULL
#  DEP_DELAY           | NULL
#  TAXI_OUT            | NULL
#  WHEELS_OFF          | NULL
#  WHEELS_ON           | NULL
#  TAXI_IN             | NULL
#  CRS_ARR_TIME        | 1637
#  ARR_TIME            | NULL
#  ARR_DELAY           | NULL
#  CANCELLED           | 1.0
#  CANCELLATION_CODE   | Pelo sistema naci...
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 127.0
#  ACTUAL_ELAPSED_TIME | NULL
#  AIR_TIME            | NULL
#  DISTANCE            | 643.0
#  CARRIER_DELAY       | NULL
#  WEATHER_DELAY       | NULL
#  NAS_DELAY           | NULL
#  SECURITY_DELAY      | NULL
#  LATE_AIRCRAFT_DELAY | NULL
#  ano                 | 2016
#  mes                 | 1
#  dia                 | 1
#  ICAO Code           | ASQ
#  Air Carrier Name    | ExpressJet Airlines
# -RECORD 13----------------------------------
#  FL_DATE             | 2016-01-01
#  OP_CARRIER_FL_NUM   | 4713
#  ORIGIN              | ORD
#  DEST                | ERI
#  CRS_DEP_TIME        | 2105
#  DEP_TIME            | NULL
#  DEP_DELAY           | NULL
#  TAXI_OUT            | NULL
#  WHEELS_OFF          | NULL
#  WHEELS_ON           | NULL
#  TAXI_IN             | NULL
#  CRS_ARR_TIME        | 2330
#  ARR_TIME            | NULL
#  ARR_DELAY           | NULL
#  CANCELLED           | 1.0
#  CANCELLATION_CODE   | Devido às condiçõ...
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 85.0
#  ACTUAL_ELAPSED_TIME | NULL
#  AIR_TIME            | NULL
#  DISTANCE            | 398.0
#  CARRIER_DELAY       | NULL
#  WEATHER_DELAY       | NULL
#  NAS_DELAY           | NULL
#  SECURITY_DELAY      | NULL
#  LATE_AIRCRAFT_DELAY | NULL
#  ano                 | 2016
#  mes                 | 1
#  dia                 | 1
#  ICAO Code           | ASQ
#  Air Carrier Name    | ExpressJet Airlines
# -RECORD 14----------------------------------
#  FL_DATE             | 2016-01-01
#  OP_CARRIER_FL_NUM   | 4642
#  ORIGIN              | ORD
#  DEST                | ORF
#  CRS_DEP_TIME        | 1349
#  DEP_TIME            | NULL
#  DEP_DELAY           | NULL
#  TAXI_OUT            | NULL
#  WHEELS_OFF          | NULL
#  WHEELS_ON           | NULL
#  TAXI_IN             | NULL
#  CRS_ARR_TIME        | 1655
#  ARR_TIME            | NULL
#  ARR_DELAY           | NULL
#  CANCELLED           | 1.0
#  CANCELLATION_CODE   | Por transportadora
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 126.0
#  ACTUAL_ELAPSED_TIME | NULL
#  AIR_TIME            | NULL
#  DISTANCE            | 717.0
#  CARRIER_DELAY       | NULL
#  WEATHER_DELAY       | NULL
#  NAS_DELAY           | NULL
#  SECURITY_DELAY      | NULL
#  LATE_AIRCRAFT_DELAY | NULL
#  ano                 | 2016
#  mes                 | 1
#  dia                 | 1
#  ICAO Code           | ASQ
#  Air Carrier Name    | ExpressJet Airlines
# -RECORD 15----------------------------------
#  FL_DATE             | 2016-01-01
#  OP_CARRIER_FL_NUM   | 5270
#  ORIGIN              | MSP
#  DEST                | STL
#  CRS_DEP_TIME        | 1500
#  DEP_TIME            | NULL
#  DEP_DELAY           | NULL
#  TAXI_OUT            | NULL
#  WHEELS_OFF          | NULL
#  WHEELS_ON           | NULL
#  TAXI_IN             | NULL
#  CRS_ARR_TIME        | 1640
#  ARR_TIME            | NULL
#  ARR_DELAY           | NULL
#  CANCELLED           | 1.0
#  CANCELLATION_CODE   | Por transportadora
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 100.0
#  ACTUAL_ELAPSED_TIME | NULL
#  AIR_TIME            | NULL
#  DISTANCE            | 448.0
#  CARRIER_DELAY       | NULL
#  WEATHER_DELAY       | NULL
#  NAS_DELAY           | NULL
#  SECURITY_DELAY      | NULL
#  LATE_AIRCRAFT_DELAY | NULL
#  ano                 | 2016
#  mes                 | 1
#  dia                 | 1
#  ICAO Code           | ASQ
#  Air Carrier Name    | ExpressJet Airlines
# -RECORD 16----------------------------------
#  FL_DATE             | 2016-01-01
#  OP_CARRIER_FL_NUM   | 5204
#  ORIGIN              | GRR
#  DEST                | MSP
#  CRS_DEP_TIME        | 1315
#  DEP_TIME            | NULL
#  DEP_DELAY           | NULL
#  TAXI_OUT            | NULL
#  WHEELS_OFF          | NULL
#  WHEELS_ON           | NULL
#  TAXI_IN             | NULL
#  CRS_ARR_TIME        | 1355
#  ARR_TIME            | NULL
#  ARR_DELAY           | NULL
#  CANCELLED           | 1.0
#  CANCELLATION_CODE   | Por transportadora
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 100.0
#  ACTUAL_ELAPSED_TIME | NULL
#  AIR_TIME            | NULL
#  DISTANCE            | 408.0
#  CARRIER_DELAY       | NULL
#  WEATHER_DELAY       | NULL
#  NAS_DELAY           | NULL
#  SECURITY_DELAY      | NULL
#  LATE_AIRCRAFT_DELAY | NULL
#  ano                 | 2016
#  mes                 | 1
#  dia                 | 1
#  ICAO Code           | ASQ
#  Air Carrier Name    | ExpressJet Airlines
# -RECORD 17----------------------------------
#  FL_DATE             | 2016-01-01
#  OP_CARRIER_FL_NUM   | 5204
#  ORIGIN              | MSP
#  DEST                | GRR
#  CRS_DEP_TIME        | 1000
#  DEP_TIME            | NULL
#  DEP_DELAY           | NULL
#  TAXI_OUT            | NULL
#  WHEELS_OFF          | NULL
#  WHEELS_ON           | NULL
#  TAXI_IN             | NULL
#  CRS_ARR_TIME        | 1240
#  ARR_TIME            | NULL
#  ARR_DELAY           | NULL
#  CANCELLED           | 1.0
#  CANCELLATION_CODE   | Por transportadora
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 100.0
#  ACTUAL_ELAPSED_TIME | NULL
#  AIR_TIME            | NULL
#  DISTANCE            | 408.0
#  CARRIER_DELAY       | NULL
#  WEATHER_DELAY       | NULL
#  NAS_DELAY           | NULL
#  SECURITY_DELAY      | NULL
#  LATE_AIRCRAFT_DELAY | NULL
#  ano                 | 2016
#  mes                 | 1
#  dia                 | 1
#  ICAO Code           | ASQ
#  Air Carrier Name    | ExpressJet Airlines
# -RECORD 18----------------------------------
#  FL_DATE             | 2016-01-01
#  OP_CARRIER_FL_NUM   | 5920
#  ORIGIN              | TVC
#  DEST                | ORD
#  CRS_DEP_TIME        | 604
#  DEP_TIME            | NULL
#  DEP_DELAY           | NULL
#  TAXI_OUT            | NULL
#  WHEELS_OFF          | NULL
#  WHEELS_ON           | NULL
#  TAXI_IN             | NULL
#  CRS_ARR_TIME        | 629
#  ARR_TIME            | NULL
#  ARR_DELAY           | NULL
#  CANCELLED           | 1.0
#  CANCELLATION_CODE   | Pelo sistema naci...
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 85.0
#  ACTUAL_ELAPSED_TIME | NULL
#  AIR_TIME            | NULL
#  DISTANCE            | 224.0
#  CARRIER_DELAY       | NULL
#  WEATHER_DELAY       | NULL
#  NAS_DELAY           | NULL
#  SECURITY_DELAY      | NULL
#  LATE_AIRCRAFT_DELAY | NULL
#  ano                 | 2016
#  mes                 | 1
#  dia                 | 1
#  ICAO Code           | ASQ
#  Air Carrier Name    | ExpressJet Airlines
# -RECORD 19----------------------------------
#  FL_DATE             | 2016-01-01
#  OP_CARRIER_FL_NUM   | 5784
#  ORIGIN              | IAH
#  DEST                | LFT
#  CRS_DEP_TIME        | 1015
#  DEP_TIME            | NULL
#  DEP_DELAY           | NULL
#  TAXI_OUT            | NULL
#  WHEELS_OFF          | NULL
#  WHEELS_ON           | NULL
#  TAXI_IN             | NULL
#  CRS_ARR_TIME        | 1116
#  ARR_TIME            | NULL
#  ARR_DELAY           | NULL
#  CANCELLED           | 1.0
#  CANCELLATION_CODE   | Pelo sistema naci...
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 61.0
#  ACTUAL_ELAPSED_TIME | NULL
#  AIR_TIME            | NULL
#  DISTANCE            | 201.0
#  CARRIER_DELAY       | NULL
#  WEATHER_DELAY       | NULL
#  NAS_DELAY           | NULL
#  SECURITY_DELAY      | NULL
#  LATE_AIRCRAFT_DELAY | NULL
#  ano                 | 2016
#  mes                 | 1
#  dia                 | 1
#  ICAO Code           | ASQ
#  Air Carrier Name    | ExpressJet Airlines
# only showing top 20 rows

# %%
# Renomear coluna para melhor entendimento
df_cancelados = df_cancelados.withColumnRenamed(
    "CANCELLATION_CODE", "motivo_cancelamento"
)

# %%
# Agrupar os dados por motivo do cancelamento e a quantidade de voos
# relacionados
df_voos_cancelados_codigos = (
    # forma de agrupamento
    df_cancelados.groupby("motivo_cancelamento")
    # forma de resumir os dados
    .count()
    # renomeando a nova coluna criada
    .withColumnRenamed("count", "quantidade")
)

# Visulizar os dados
df_voos_cancelados_codigos.show(truncate=False)
# Out:
# +-----------------------------------------+----------+
# |motivo_cancelamento                      |quantidade|
# +-----------------------------------------+----------+
# |Devido às condições climáticas           |34465     |
# |Pelo sistema nacional de transporte aéreo|11091     |
# |Por transportadora                       |20279     |
# |Por razões de segurança                  |26        |
# +-----------------------------------------+----------+

# %%
# Passando as informações do cluster Spark para o kernel do python e criando um
# dataframe pandas
pdf_voos_cancelados_codigos = df_voos_cancelados_codigos.toPandas()

# %%
# Agora o dataframe pode ser tratado como um dataframe pandas

# Visualizando as primeiras linhas do dataset
pdf_voos_cancelados_codigos.head()
# Out:
#                          motivo_cancelamento  quantidade
# 0             Devido às condições climáticas       34465
# 1  Pelo sistema nacional de transporte aéreo       11091
# 2                         Por transportadora       20279
# 3                    Por razões de segurança          26

# %%
# Visualizando as variáveis univiaradas
pdf_voos_cancelados_codigos.describe()
# Out:
#          quantidade
# count      4.000000
# mean   16465.250000
# std    14579.291166
# min       26.000000
# 25%     8324.750000
# 50%    15685.000000
# 75%    23825.500000
# max    34465.000000

# %%
# Verificando o tipo do dataframe pyspark
print(type(df_voos_cancelados_codigos))
# Out:
# <class 'pyspark.sql.dataframe.DataFrame'>

# %%
# Verificando o tipo do dataframe pandas
print(type(pdf_voos_cancelados_codigos))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# #### Análise Gráfica

# %%
# criando um gráfico de barras com os dados retornados

# definindo o tamanho da imagem
plt.figure(figsize=(16,12), dpi=300) 

# criando o gráfico de colunas
ax = sns.barplot(
    pdf_voos_cancelados_codigos.sort_values(by="quantidade", ascending=False),
    x="motivo_cancelamento",
    y="quantidade",
    color="#8e44ad"
)
# alterando título e os rótuos dos eixos x e y
ax.set_ylabel("Quantidade voos cancelados", fontsize=14)
ax.set_xlabel("Motivo dos cancelamentos", fontsize=14)
ax.set_title("Voos cancelados e seus motivos", fontsize=14)

# adicionando os labels nas colunas
ax.bar_label(ax.containers[0], fontsize=12)

# plotar o gráfico
plt.show()

# %%
# verificando dados das transportadoras

df_agrupado_companhias = df.groupby("Air Carrier Name").agg(
    # resumir o dado pela média do atraso na chegada e contagem de voos cancelados e total
    # média atraso na chegada
    F.avg("ARR_DELAY").alias("media_atraso"),
    # somatório de voos cancelados
    F.sum("CANCELLED").alias("voos_cancelados"),
    # contagem da quantidade de voos
    F.count(F.lit(1)).alias("quantidade_de_voos"),
)

# mostrar os dados
df_agrupado_companhias.show()
# Out:
# +--------------------+-------------------+---------------+------------------+
# |    Air Carrier Name|       media_atraso|voos_cancelados|quantidade_de_voos|
# +--------------------+-------------------+---------------+------------------+
# |    Skywest Airlines|  4.256732115692655|         8446.0|            605933|
# |                NULL|  7.355040508665778|          669.0|             69121|
# |     United Airlines| 1.7556160463776733|         5470.0|            545067|
# |   Hawaiian Airlines| -0.072610234112839|          118.0|             76789|
# | ExpressJet Airlines|  5.439868990877946|        11889.0|            490990|
# |   Frontier Airlines|  7.790653787103378|         1179.0|             95121|
# |   American Airlines|  5.085088727463136|        10867.0|            914495|
# |     Delta Air Lines|-0.5561917600251283|         4116.0|            922746|
# |     Alaska Airlines| -2.197627447972593|          815.0|            177280|
# |     Spirit Airlines|   9.32820914376048|         2629.0|            138199|
# |Jetblue Airways C...|  8.052638204963113|         3797.0|            282473|
# |  Southwest Airlines| 3.9023048557063804|        15866.0|           1299444|
# +--------------------+-------------------+---------------+------------------+

# %%
# passando as informações do driver para a memória do kernel e criando um dataframe pandas
pdf_agrupado_companhias = df_agrupado_companhias.toPandas()

# ajustando os dados para organizar os valores pela media do atraso
pdf_agrupado_companhias = pdf_agrupado_companhias.sort_values(
    by="media_atraso", ascending=True
).round(1)

# %%
# criando gráfico com os dados retornados

# definindo o tamanho da imagem
plt.figure(figsize=(16, 10), dpi=300)

# criando o gráfico de colunas
ax = sns.barplot(pdf_agrupado_companhias,
                 color="#8e44ad",
                 x="Air Carrier Name", 
                 y="media_atraso")

# alterando título e os rótuos dos eixos x e y
ax.set_ylabel("Média de atraso (min)", fontsize=14)
ax.set_xlabel("Código da trasportadora", fontsize=14)
ax.set_title("Média de atraso nas transportadoras", fontsize=14)

# adicionando os labels nas colunas
ax.bar_label(ax.containers[0], fontsize=12)
ax.tick_params(axis='x', rotation=90)

# adicionar linha auxiliar no eixo y = 0
plt.axhline(y=0, color="gray", linestyle="--")

# plotar o gráfico
plt.show()

# %% [markdown]
# #### Lendo Múltiplos Dados Estruturados

# %%
# Coletar a informação do diretório atual#
caminho_atual = os.getcwd()

# Lista de anos para carregar os dados
lista_anos = ["2016", "2017"]

# Lista que vai receber os caminhos completos
caminho_arquivos = []

# Percorrer cada ano da lista de anos
for ano in lista_anos:
    caminho = f"{caminho_atual}/datasets/{ano}.csv"
    caminho_arquivos.append(caminho)
# Out:
# ['c:\\Users\\guilh\\OneDrive\\MBA\\Big Data e Deployment\\big_data_spark/datasets/2016.csv', 'c:\\Users\\guilh\\OneDrive\\MBA\\Big Data e Deployment\\big_data_spark/datasets/2017.csv']

# %%
# Criar um dataframe com múltiplas fontes de bases de dados
df = spark.read.csv(caminho_arquivos, header=True, inferSchema=True)

# %%
# Contagem de linhas do dataframe criado
df.count()
# Out:
# 11292279

# %%
# Coletando o ano da variável FL_DATE
df = df.withColumn("ano", F.year(df["FL_DATE"]))

# Coletando o mês da variável FL_DATE
df = df.withColumn("mes", F.month(df["FL_DATE"]))

# %%
# Agrupando e resumindo agora os dados por ano
df.groupby("ano").agg(F.avg("ARR_DELAY").alias("media_atraso")).show()
# Out:
# +----+------------------+
# | ano|      media_atraso|
# +----+------------------+
# |2016|3.5192899427515894|
# |2017|   4.3263569087054|
# +----+------------------+

# %%
# Agrupando e resumindo agora os dados por ano e por mês
df.groupby("ano", "mes").agg(
    F.avg("ARR_DELAY").alias("media_atraso")
).orderBy("ano", "mes").show()
# Out:
# +----+---+-------------------+
# | ano|mes|       media_atraso|
# +----+---+-------------------+
# |2016|  1|  1.533653513286468|
# |2016|  2| 0.6652991970622235|
# |2016|  3| 3.1459138871633643|
# |2016|  4| 0.6968198081024388|
# |2016|  5| 2.2490057812950184|
# |2016|  6|  7.154742200301092|
# |2016|  7| 10.384150586932357|
# |2016|  8|  8.013417284908106|
# |2016|  9|0.49918242523610235|
# |2016| 10|-0.2230462516524559|
# |2016| 11|-1.8610726847860712|
# |2016| 12|  8.664734017499983|
# |2017|  1|  6.954483731192212|
# |2017|  2| 0.6875590551181102|
# |2017|  3|  4.306398360443615|
# |2017|  4|  7.322608136076665|
# |2017|  5|  6.029889865233924|
# |2017|  6|  9.132847670438348|
# |2017|  7|  8.295147670495197|
# |2017|  8|  6.692594592532966|
# +----+---+-------------------+
# only showing top 20 rows

# %%
# Retirando o dataframe spark da memória e do disco
df.unpersist()
# Out:
# DataFrame[FL_DATE: date, OP_CARRIER: string, OP_CARRIER_FL_NUM: int, ORIGIN: string, DEST: string, CRS_DEP_TIME: int, DEP_TIME: double, DEP_DELAY: double, TAXI_OUT: double, WHEELS_OFF: double, WHEELS_ON: double, TAXI_IN: double, CRS_ARR_TIME: int, ARR_TIME: double, ARR_DELAY: double, CANCELLED: double, CANCELLATION_CODE: string, DIVERTED: double, CRS_ELAPSED_TIME: double, ACTUAL_ELAPSED_TIME: double, AIR_TIME: double, DISTANCE: double, CARRIER_DELAY: double, WEATHER_DELAY: double, NAS_DELAY: double, SECURITY_DELAY: double, LATE_AIRCRAFT_DELAY: double, Unnamed: 27: string, ano: int, mes: int]

# %%
# Finalizando a aplicação Spark
spark.stop()

# %% [markdown]
# ### FIM!
